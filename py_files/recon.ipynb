# %%
import pandas as pd
import numpy as np
import re as re

pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows',100)

# %%
# Take in Excel

itemized = pd.read_excel('/Users/danielsagher/Dropbox/Documents/projects/nautical_reconciliation/excel/Nautical 11-2024.xlsx', header=2, sheet_name=0)
invoice_data = pd.read_excel('/Users/danielsagher/Dropbox/Documents/projects/nautical_reconciliation/excel/Nautical 11-2024.xlsx', sheet_name=1)
qbo = pd.read_excel('/Users/danielsagher/Dropbox/Documents/projects/nautical_reconciliation/excel/QBO_customers.xlsx')
amt = pd.read_excel('/Users/danielsagher/Dropbox/Documents/projects/nautical_reconciliation/excel/Exensiv.xlsx', sheet_name='AMT')
gp_acoustics = pd.read_excel('/Users/danielsagher/Dropbox/Documents/projects/nautical_reconciliation/excel/Exensiv.xlsx', sheet_name='GPAcoustics')

# %% [markdown]
# # **Invoice Data** <-> **QBO**
#
# ## - Compare **Invoice Data** [`Customer PO #`] to **QBO** [`Display_Name`]

# %%
# Merge QuickBooks and FedEx to find shared values

#! Check if Display name is the only key to compare against

qbo_found = pd.merge(qbo, invoice_data, right_on='Customer PO #', left_on= 'Display_Name', how='inner')

# %%
# Number of PO's Found in QuickBooks

print(f'Unique Found POs: {len(qbo_found['Display_Name'].drop_duplicates())}',
      f'Total Found POs: {len(qbo_found)}', sep='\n')
# Out:
# Unique Found POs: 6
# Total Found POs: 2218

# %% [markdown]
# ### - Add not found values to new table: `not_found`

# %%
# Add unique Customer PO's not found in quickbooks to a unique list

lst = set()
for i in invoice_data['Customer PO #']:
    if i not in list(qbo_found['Display_Name'].unique()):
        lst.add(i)

# %%
len(lst)
# Out:
# 84

# %%
not_found = pd.DataFrame()
not_found['Customer PO #'] = pd.DataFrame(lst)
not_found = not_found.merge(invoice_data[['Customer PO #',  
                            'Reference',
                            'Reference 2',
                            'Total Charges',
                            'Receiver Name',
                            'Receiver Company',
                            'Receiver Address',
                            'Tracking #']],
                             on='Customer PO #', how='left')
not_found
# Out:
#                  Customer PO #                 Reference Reference 2  \
# 0          113-9410880-0465011                     14324         NaN
# 1           700670006/SD266461                     10558         NaN
# 2     Nautical/Arrived/Splenda         ARRCO-22724-00027         NaN
# 3     Nautical/Arrived/Splenda         ARRCO-22724-00027         NaN
# 4     Nautical/Arrived/Splenda         ARRCO-22724-00027         NaN
# ...                        ...                       ...         ...
# 2750        RECESS-22124-00019  Nautical/Recess/Rockstar         NaN
# 2751        RECESS-22124-00019  Nautical/Recess/Rockstar         NaN
# 2752        RECESS-22124-00019  Nautical/Recess/Rockstar         NaN
# 2753        RECESS-22124-00019  Nautical/Recess/Rockstar         NaN
# 2754        RECESS-22124-00019  Nautical/Recess/Rockstar         NaN
#
#       Total Charges           Receiver Name                 Receiver Company  \
# 0            106.98           CHIP BARTLETT                    CHIP BARTLETT
# 1              4.92  MUSICAL FULFILLMENT OH           MUSICAL FULFILLMENT OH
# 2              5.10               BETH RUGE                   SPLENDA STEVIA
# 3              4.92                JENNIFER  CAROLINE R KLUTTZ, MS, RDN, LDN
# 4              5.23    Nautical Fulfillment             Nautical Fulfillment
# ...             ...                     ...                              ...
# 2750           9.96       COMMUNITY MANAGER           WEWORK - 400 CONCAR DR
# 2751           9.96       COMMUNITY MANAGER             WEWORK - 1 BELVEDERE
# 2752          20.62       COMMUNITY MANAGER          WEWORK - 450 PARK AVE S
# 2753           9.45       COMMUNITY MANAGER              WEWORK - 33 ARCH ST
# 2754           6.97       COMMUNITY MANAGER                    WEWORK - CODA
#
#                    Receiver Address    Tracking #
# 0               43 PASEO VESPERTINO  281378830569
# 1                    1040 N WYNN RD  280881667358
# 2           14390 CLAY TERRACE BLVD  418132348850
# 3     8810 BLAKENEY PROFESSIONAL DR  418132349099
# 4                  16100 W 116th St  418132350276
# ...                             ...           ...
# 2750                  400 CONCAR DR  426933225007
# 2751                 1 BELVEDERE PL  426933223493
# 2752                 450 PARK AVE S  426933225132
# 2753                     33 ARCH ST  426933224868
# 2754          756 W PEACHTREE ST NW  426933226323
#
# [2755 rows x 8 columns]

# %% [markdown]
# # **Invoice Data** [`Reference`] <-> **Extensiv** [`Reference`]
#
# ## - For all **Invoice Data** [`Customer PO #`] not in **QBO** [`Display Name`]

# %% [markdown]
# ### - Create RegEx token function

# %%
# Create Regex Tokens

def reg_tokenizer(value):

    '''
    Input: Value of each column in Reference and Reference 2
    Output: RegEx object
    '''

    with_letters = re.sub(r'[a-zA-Z]+',r'\\w+' , str(value))

    with_numbers = re.sub(r'\d+', r'\\d+', with_letters)

    with_spaces = re.sub(r'\s+', r'\\s+', with_numbers)

    final = re.compile(with_spaces)
    
    return final

# %%
# RegEx Test

for i in range(len(not_found['Customer PO #'])):

    test = reg_tokenizer(not_found['Customer PO #'][i])
    
    match = re.fullmatch(test, str(not_found['Customer PO #'][i]))
    
    # print(f'{test}, original: {not_found['Customer PO #'][i]}, match: {match.group(0)}')

# %% [markdown]
# ### - Add RegEx column to `not_found` with [Reference] patterns

# %%
# Add Pattern column

token_lst = []

for i in not_found['Reference']:
    token_lst.append(reg_tokenizer(i))

not_found['Pattern'] = token_lst

# %%
# Fedex columns with added Reference pattern

not_found
# Out:
#                  Customer PO #                 Reference Reference 2  \
# 0          113-9410880-0465011                     14324         NaN
# 1           700670006/SD266461                     10558         NaN
# 2     Nautical/Arrived/Splenda         ARRCO-22724-00027         NaN
# 3     Nautical/Arrived/Splenda         ARRCO-22724-00027         NaN
# 4     Nautical/Arrived/Splenda         ARRCO-22724-00027         NaN
# ...                        ...                       ...         ...
# 2750        RECESS-22124-00019  Nautical/Recess/Rockstar         NaN
# 2751        RECESS-22124-00019  Nautical/Recess/Rockstar         NaN
# 2752        RECESS-22124-00019  Nautical/Recess/Rockstar         NaN
# 2753        RECESS-22124-00019  Nautical/Recess/Rockstar         NaN
# 2754        RECESS-22124-00019  Nautical/Recess/Rockstar         NaN
#
#       Total Charges           Receiver Name                 Receiver Company  \
# 0            106.98           CHIP BARTLETT                    CHIP BARTLETT
# 1              4.92  MUSICAL FULFILLMENT OH           MUSICAL FULFILLMENT OH
# 2              5.10               BETH RUGE                   SPLENDA STEVIA
# 3              4.92                JENNIFER  CAROLINE R KLUTTZ, MS, RDN, LDN
# 4              5.23    Nautical Fulfillment             Nautical Fulfillment
# ...             ...                     ...                              ...
# 2750           9.96       COMMUNITY MANAGER           WEWORK - 400 CONCAR DR
# 2751           9.96       COMMUNITY MANAGER             WEWORK - 1 BELVEDERE
# 2752          20.62       COMMUNITY MANAGER          WEWORK - 450 PARK AVE S
# 2753           9.45       COMMUNITY MANAGER              WEWORK - 33 ARCH ST
# 2754           6.97       COMMUNITY MANAGER                    WEWORK - CODA
#
#                    Receiver Address    Tracking #  \
# 0               43 PASEO VESPERTINO  281378830569
# 1                    1040 N WYNN RD  280881667358
# 2           14390 CLAY TERRACE BLVD  418132348850
# 3     8810 BLAKENEY PROFESSIONAL DR  418132349099
# 4                  16100 W 116th St  418132350276
# ...                             ...           ...
# 2750                  400 CONCAR DR  426933225007
# 2751                 1 BELVEDERE PL  426933223493
# 2752                 450 PARK AVE S  426933225132
# 2753                     33 ARCH ST  426933224868
# 2754          756 W PEACHTREE ST NW  426933226323
#
#                            Pattern
# 0               re.compile('\\d+')
# 1               re.compile('\\d+')
# 2     re.compile('\\w+-\\d+-\\d+')
# 3     re.compile('\\w+-\\d+-\\d+')
# 4     re.compile('\\w+-\\d+-\\d+')
# ...                            ...
# 2750  re.compile('\\w+/\\w+/\\w+')
# 2751  re.compile('\\w+/\\w+/\\w+')
# 2752  re.compile('\\w+/\\w+/\\w+')
# 2753  re.compile('\\w+/\\w+/\\w+')
# 2754  re.compile('\\w+/\\w+/\\w+')
#
# [2755 rows x 9 columns]

# %% [markdown]
# ### - Compare `not found`[Pattern] to values in Extensiv Tables

# %%
# Compare Reference Patterns against every value in Extensiv Table

def find_col_match(ext_table, ref_pattern):

    col_lst = set()

    for col in ext_table.columns:

        for value in ext_table[col]:

            if re.fullmatch(ref_pattern,str(value)):

                col_lst.add(col)
                break
            
            else:
                break

    if len(col_lst) != 0:
        return col_lst
    else:
        return None

# %%
# Test \d+ to AMT table 

find_col_match(amt, not_found['Pattern'][1])
# Out:
# {'AsnCandidate',
#  'Column1',
#  'CreatedByIdentifier.Id',
#  'Custom.TotalResults',
#  'CustomerIdentifier.Id',
#  'Index',
#  'LastModifiedByIdentifier.Id',
#  'LoadedState',
#  'OrderId',
#  'ParcelLabelType',
#  'RouteCandidate',
#  'RoutingInfo.BillOfLading',
#  'ShipTo.Zip',
#  'Status',
#  'TransactionEntryType',
#  'WarehouseTransactionSourceType'}

# %%
# Check AMT table

amt[['AsnCandidate',
 'Column1',
 'CreatedByIdentifier.Id',
 'Custom.TotalResults',
 'CustomerIdentifier.Id',
 'Index',
 'LastModifiedByIdentifier.Id',
 'LoadedState',
 'OrderId',
 'ParcelLabelType',
 'RouteCandidate',
 'RoutingInfo.BillOfLading',
 'ShipTo.Zip',
 'Status',
 'TransactionEntryType',
 'WarehouseTransactionSourceType']].head()
# Out:
#    AsnCandidate  Column1  CreatedByIdentifier.Id  Custom.TotalResults  \
# 0             0        0                      10                 1044
# 1             0        0                      10                 1044
# 2             0        0                      10                 1044
# 3             0        0                      10                 1044
# 4             0        0                      10                 1044
#
#    CustomerIdentifier.Id  Index  LastModifiedByIdentifier.Id  LoadedState  \
# 0                     11      1                           10            0
# 1                     11      1                           10            0
# 2                     11      1                           10            0
# 3                     11      1                           10            0
# 4                     11      1                           10            0
#
#    OrderId  ParcelLabelType  RouteCandidate RoutingInfo.BillOfLading  \
# 0      363                0               0                       17
# 1      363                0               0                       17
# 2      363                0               0                       17
# 3      363                0               0                       17
# 4      363                0               0                       17
#
#   ShipTo.Zip  Status  TransactionEntryType  WarehouseTransactionSourceType
# 0      52404       1                     1                               1
# 1      52404       1                     1                               1
# 2      52404       1                     1                               1
# 3      52404       1                     1                               1
# 4      52404       1                     1                               1

# %% [markdown]
# ### - Compare all `not_found`[Reference] values to Extensiv Table

# %%
def find_extensiv_reference_columns(ext_table):

    match_dct = dict()
    suffix = 0

    for i, v in enumerate(not_found['Reference']):

        #! Suffix Maker WIP
        if i != 0 and v == not_found['Reference'][i-1]:
            
            suffix += 1
            v = f'{v}-s{suffix}'
            
            
        elif i != 0 and v != not_found['Reference'][i-1]:
            suffix = 0
        else:
            continue 
            
        match_lst = find_col_match(ext_table, not_found['Pattern'][i])

        if match_lst is not None and not pd.isna(v):  
            
            match_dct[v] = {'match_lst': match_lst,
                            'Total Charges': not_found['Total Charges'][i],
                            'Tracking #': not_found['Tracking #'][i]}

    return match_dct

# %%
# Test Find column matches

amt_match_dct = find_extensiv_reference_columns(amt)
gp_acoustics_dct = find_extensiv_reference_columns(gp_acoustics)

# %%
# Reference numbers in FedEx and matching columns in Extensiv 

gp_acoustics_dct
# Out:
# {10558: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 4.92,
#   'Tracking #': 280881667358},
#  10556: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 4.92,
#   'Tracking #': 280881537650},
#  10562: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 10.63,
#   'Tracking #': 280881473027},
#  '10562-s1': {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 9.39,
#   'Tracking #': 280881474940},
#  11397: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 9.56,
#   'Tracking #': 280768308100},
#  'GP Acoustics': {'match_lst': {'CreatedByIdentifier.Name',
#    'CustomerIdentifier.Name',
#    'LastModifiedByIdentifier.Name',
#    'ShipTo.City'},
#   'Total Charges': 11.9,
#   'Tracking #': 418132348770},
#  'GP Acoustics-s1': {'match_lst': {'CreatedByIdentifier.Name',
#    'CustomerIdentifier.Name',
#    'LastModifiedByIdentifier.Name',
#    'ShipTo.City'},
#   'Total Charges': 11.9,
#   'Tracking #': 418132348758},
#  'GP Acoustics-s2': {'match_lst': {'CreatedByIdentifier.Name',
#    'CustomerIdentifier.Name',
#    'LastModifiedByIdentifier.Name',
#    'ShipTo.City'},
#   'Total Charges': 11.9,
#   'Tracking #': 418132348769},
#  'GP Acoustics-s3': {'match_lst': {'CreatedByIdentifier.Name',
#    'CustomerIdentifier.Name',
#    'LastModifiedByIdentifier.Name',
#    'ShipTo.City'},
#   'Total Charges': 11.9,
#   'Tracking #': 418132348747},
#  10548: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 4.85,
#   'Tracking #': 280881319542},
#  13730: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 22.44,
#   'Tracking #': 281241623171},
#  '13730-s1': {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 12.15,
#   'Tracking #': 281241622510},
#  '13730-s2': {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 22.44,
#   'Tracking #': 281241625601},
#  '13730-s3': {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 22.44,
#   'Tracking #': 281241624237},
#  13282: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 106.98,
#   'Tracking #': 281075499427},
#  14273: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 103.43,
#   'Tracking #': 281378876230},
#  11934: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 10.85,
#   'Tracking #': 280986974282},
#  13405: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 103.43,
#   'Tracking #': 281138823384},
#  198460: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 11.43,
#   'Tracking #': 418132350302},
#  10564: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 5.18,
#   'Tracking #': 280882000233},
#  10563: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 5.56,
#   'Tracking #': 280881729544},
#  13765: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 17.18,
#   'Tracking #': 281248581945},
#  '13765-s1': {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 18.25,
#   'Tracking #': 281248585790},
#  '13765-s2': {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 17.18,
#   'Tracking #': 281248582091},
#  '13765-s3': {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 18.25,
#   'Tracking #': 281248583672},
#  13157: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 9.39,
#   'Tracking #': 281058904347},
#  10554: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 6.54,
#   'Tracking #': 280881245477},
#  14821: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 103.43,
#   'Tracking #': 281566654210},
#  14866: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 103.43,
#   'Tracking #': 281581789890},
#  10569: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 5.91,
#   'Tracking #': 280881789594},
#  13390: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 23.69,
#   'Tracking #': 281142406523},
#  '13390-s1': {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 23.31,
#   'Tracking #': 281142405045},
#  'Customer Box': {'match_lst': {'CreatedByIdentifier.Name',
#    'CustomerIdentifier.Name',
#    'LastModifiedByIdentifier.Name',
#    'ShipTo.City'},
#   'Total Charges': 11.65,
#   'Tracking #': 418132350265},
#  14678: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 21.44,
#   'Tracking #': 418132350313},
#  '14678-s1': {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 19.96,
#   'Tracking #': 418132350335},
#  '14678-s2': {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 25.12,
#   'Tracking #': 418132350324},
#  11614: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 101.28,
#   'Tracking #': 280862887420},
#  14743: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 7.29,
#   'Tracking #': 281567086557},
#  198370: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 23.35,
#   'Tracking #': 418132350368},
#  'Whill Inc': {'match_lst': {'CreatedByIdentifier.Name',
#    'CustomerIdentifier.Name',
#    'LastModifiedByIdentifier.Name',
#    'ShipTo.City'},
#   'Total Charges': 39.0,
#   'Tracking #': 418132350379},
#  10474: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 6.51,
#   'Tracking #': 281571300596},
#  14704: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 20.66,
#   'Tracking #': 281669144489},
#  '14704-s1': {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 4.85,
#   'Tracking #': 281669148820},
#  14794: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 106.98,
#   'Tracking #': 281546944248},
#  14797: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 11.14,
#   'Tracking #': 281570010710},
#  14800: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 11.14,
#   'Tracking #': 281570078533},
#  14801: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 11.14,
#   'Tracking #': 281570127730},
#  14802: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 35.46,
#   'Tracking #': 281570230637},
#  14811: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 19.46,
#   'Tracking #': 281570277690},
#  14814: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 11.14,
#   'Tracking #': 281570465854},
#  14836: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 11.14,
#   'Tracking #': 281570352428},
#  14869: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 11.14,
#   'Tracking #': 281591257642},
#  14877: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 11.14,
#   'Tracking #': 281591313370},
#  14880: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 11.14,
#   'Tracking #': 281591361199},
#  14881: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 11.12,
#   'Tracking #': 281648839995},
#  14979: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 11.12,
#   'Tracking #': 281670208579},
#  15021: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 11.88,
#   'Tracking #': 281706929401},
#  355344: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 6.94,
#   'Tracking #': 281756336950},
#  '355344-s1': {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 6.8,
#   'Tracking #': 281756340286},
#  '355344-s2': {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 6.8,
#   'Tracking #': 281756336938},
#  '355344-s3': {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 6.53,
#   'Tracking #': 281756339363},
#  11348: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 106.73,
#   'Tracking #': 280754149646},
#  14901: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 106.85,
#   'Tracking #': 281636958213},
#  11844: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 7.7,
#   'Tracking #': 280986894281},
#  11391: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 9.56,
#   'Tracking #': 280766989314},
#  '11391-s1': {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 11.18,
#   'Tracking #': 280766986668},
#  15000: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 98.93,
#   'Tracking #': 281720177427},
#  13158: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 24.42,
#   'Tracking #': 281058966643},
#  '13158-s1': {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 24.42,
#   'Tracking #': 281058965268},
#  15151: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 11.96,
#   'Tracking #': 281708821710},
#  11627: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 110.56,
#   'Tracking #': 280863094183},
#  11912: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 8.54,
#   'Tracking #': 280986780422},
#  10557: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 5.55,
#   'Tracking #': 280881846057},
#  13700: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 15.81,
#   'Tracking #': 281249653359},
#  11584: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 107.44,
#   'Tracking #': 280862770590},
#  10559: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 12.1,
#   'Tracking #': 280882098840},
#  13903: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 4.85,
#   'Tracking #': 281242712302},
#  10560: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 8.21,
#   'Tracking #': 280881903399},
#  11396: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 9.56,
#   'Tracking #': 280807219242},
#  15116: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 5.17,
#   'Tracking #': 281752495934},
#  10555: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 5.85,
#   'Tracking #': 280881370665},
#  10561: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 7.47,
#   'Tracking #': 280881613185},
#  'BottleNecker Sample': {'match_lst': {'CreatedByIdentifier.Name',
#    'CustomerIdentifier.Name',
#    'LastModifiedByIdentifier.Name',
#    'ShipTo.City'},
#   'Total Charges': 4.85,
#   'Tracking #': 418132348736},
#  11905: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 106.73,
#   'Tracking #': 280981724902},
#  10565: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 14.17,
#   'Tracking #': 280882160702},
#  11514: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 106.73,
#   'Tracking #': 280791284071},
#  11523: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 19.93,
#   'Tracking #': 280791161446},
#  14902: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 110.68,
#   'Tracking #': 281637062560},
#  14552: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 106.98,
#   'Tracking #': 281435191263},
#  11503: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 106.73,
#   'Tracking #': 280791342402},
#  14371: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 9.62,
#   'Tracking #': 281397637770},
#  10567: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 9.56,
#   'Tracking #': 280882052528},
#  11653: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 30.42,
#   'Tracking #': 280887141570},
#  '11653-s1': {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 15.9,
#   'Tracking #': 280887141179},
#  '11653-s2': {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 20.17,
#   'Tracking #': 280887148015},
#  '11653-s3': {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 22.14,
#   'Tracking #': 280887144903},
#  '11653-s4': {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 21.44,
#   'Tracking #': 280887146766},
#  'Event Sample': {'match_lst': {'CreatedByIdentifier.Name',
#    'CustomerIdentifier.Name',
#    'LastModifiedByIdentifier.Name',
#    'ShipTo.City'},
#   'Total Charges': 19.79,
#   'Tracking #': 418132348817},
#  10566: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': 9.56,
#   'Tracking #': 280881955477}}

# %% [markdown]
# ### - Compare each `not_found`[Reference] to each value in matched Extensiv columns

# %%
# Search through values in each of the matched columns in Extensiv table and look for direct match to Reference

def find_value_match(table, match_dct):

    match_lst = list()

    for reference in match_dct:

        matches = match_dct[reference]['match_lst']
        total_charges = match_dct[reference]['Total Charges']
        tracking_number = match_dct[reference]['Tracking #']

        for col in table[list(matches)]:

            for i, val in enumerate(table[col]):
                    
                base_reference = re.sub(r'-s\d+$', '', str(reference))
                
                if val == reference or val == base_reference:
                    
                    match_entry = {'Reference': reference,
                                   'Name': table['CustomerIdentifier.Name'][i],
                                   'Column': col, 
                                   'Total Charges': total_charges,
                                   'Tracking #': tracking_number}

                    if match_entry not in match_lst:  
                        match_lst.append(match_entry)                        
                else:  
                    continue

    if not match_lst:      
        print(f'No Matches')

    else:
        return match_lst

# %%
# amt_found_values = find_value_match(gp_acoustics, gp_acoustics_dct)
gp_found_values = find_value_match(gp_acoustics, gp_acoustics_dct)

# %%
gp_found_values
# Out:
# [{'Reference': 10558,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 4.92,
#   'Tracking #': 280881667358},
#  {'Reference': 10556,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 4.92,
#   'Tracking #': 280881537650},
#  {'Reference': 10562,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 10.63,
#   'Tracking #': 280881473027},
#  {'Reference': 11397,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 9.56,
#   'Tracking #': 280768308100},
#  {'Reference': 'GP Acoustics',
#   'Name': 'GP Acoustics',
#   'Column': 'CustomerIdentifier.Name',
#   'Total Charges': 11.9,
#   'Tracking #': 418132348770},
#  {'Reference': 'GP Acoustics-s1',
#   'Name': 'GP Acoustics',
#   'Column': 'CustomerIdentifier.Name',
#   'Total Charges': 11.9,
#   'Tracking #': 418132348758},
#  {'Reference': 'GP Acoustics-s2',
#   'Name': 'GP Acoustics',
#   'Column': 'CustomerIdentifier.Name',
#   'Total Charges': 11.9,
#   'Tracking #': 418132348769},
#  {'Reference': 'GP Acoustics-s3',
#   'Name': 'GP Acoustics',
#   'Column': 'CustomerIdentifier.Name',
#   'Total Charges': 11.9,
#   'Tracking #': 418132348747},
#  {'Reference': 10548,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 4.85,
#   'Tracking #': 280881319542},
#  {'Reference': 13730,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 22.44,
#   'Tracking #': 281241623171},
#  {'Reference': 11934,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 10.85,
#   'Tracking #': 280986974282},
#  {'Reference': 10564,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 5.18,
#   'Tracking #': 280882000233},
#  {'Reference': 10563,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 5.56,
#   'Tracking #': 280881729544},
#  {'Reference': 13765,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 17.18,
#   'Tracking #': 281248581945},
#  {'Reference': 13157,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 9.39,
#   'Tracking #': 281058904347},
#  {'Reference': 10554,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 6.54,
#   'Tracking #': 280881245477},
#  {'Reference': 10569,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 5.91,
#   'Tracking #': 280881789594},
#  {'Reference': 13390,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 23.69,
#   'Tracking #': 281142406523},
#  {'Reference': 14743,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 7.29,
#   'Tracking #': 281567086557},
#  {'Reference': 11844,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 7.7,
#   'Tracking #': 280986894281},
#  {'Reference': 11391,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 9.56,
#   'Tracking #': 280766989314},
#  {'Reference': 13158,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 24.42,
#   'Tracking #': 281058966643},
#  {'Reference': 11912,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 8.54,
#   'Tracking #': 280986780422},
#  {'Reference': 10557,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 5.55,
#   'Tracking #': 280881846057},
#  {'Reference': 13700,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 15.81,
#   'Tracking #': 281249653359},
#  {'Reference': 10559,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 12.1,
#   'Tracking #': 280882098840},
#  {'Reference': 13903,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 4.85,
#   'Tracking #': 281242712302},
#  {'Reference': 10560,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 8.21,
#   'Tracking #': 280881903399},
#  {'Reference': 11396,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 9.56,
#   'Tracking #': 280807219242},
#  {'Reference': 15116,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 5.17,
#   'Tracking #': 281752495934},
#  {'Reference': 10555,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 5.85,
#   'Tracking #': 280881370665},
#  {'Reference': 10561,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 7.47,
#   'Tracking #': 280881613185},
#  {'Reference': 10565,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 14.17,
#   'Tracking #': 280882160702},
#  {'Reference': 11523,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 19.93,
#   'Tracking #': 280791161446},
#  {'Reference': 14371,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 9.62,
#   'Tracking #': 281397637770},
#  {'Reference': 10567,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 9.56,
#   'Tracking #': 280882052528},
#  {'Reference': 11653,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 30.42,
#   'Tracking #': 280887141570},
#  {'Reference': 10566,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 9.56,
#   'Tracking #': 280881955477}]

# %% [markdown]
# # **Invoice Data** [`Receiver Info`] <-> **Extensiv** [`Receiver Info`]

# %%
# Create list of FedEx References that were found in Extensiv cross-examination

found_reference_lst = list()

for i in gp_found_values:
    found_reference_lst.append(i['Reference'])
# Out:
#     Customer PO #                 Reference            Reference 2  \
# 757           NaN                       NaN                    NaN
# 758           NaN                    198370  Nautical/Whill/198370
# 759           NaN  Nautical/Arrived/Horizon                    NaN
# 760           NaN  Nautical/Arrived/Horizon                    NaN
# 761           NaN  Nautical/Arrived/Horizon                    NaN
#
#      Total Charges    Receiver Name                Receiver Company  \
# 757           6.54    SPERO PLESSAS                   SPERO PLESSAS
# 758          23.35  Salome Macaspac                       Whill Inc
# 759           7.47    Karen Maxwell  Bartlett Park District Prescho
# 760           7.47    Karen Maxwell  Bartlett Park District Prescho
# 761           7.47    Karen Maxwell  Bartlett Park District Prescho
#
#             Receiver Address    Tracking #                       Pattern
# 757         10628 GRAND BLVD  779439316825            re.compile('\\w+')
# 758        200 Sunfish Court  418132350368            re.compile('\\d+')
# 759  700 South Bartlett Road  426933217899  re.compile('\\w+/\\w+/\\w+')
# 760  700 South Bartlett Road  426933218358  re.compile('\\w+/\\w+/\\w+')
# 761  700 South Bartlett Road  426933218369  re.compile('\\w+/\\w+/\\w+')

# %%
# Create FedEx null DataFrame 

invoice_data_null = not_found[(not_found['Customer PO #'].isna()) & ~(not_found['Reference'].isin(found_reference_lst))]
invoice_data_null2 = not_found

# %%
# Create Extensiv Receiver Information tables

amt_receiver_info = amt[['ShipTo.CompanyName',
               'ShipTo.Name',
               'ShipTo.Address1',
               'CustomerIdentifier.Name']]
gp_receiver_info = gp_acoustics[['ShipTo.CompanyName',
               'ShipTo.Name',
               'ShipTo.Address1',
               'CustomerIdentifier.Name']]

amt_receiver_info_nd = amt_receiver_info.drop_duplicates(['ShipTo.CompanyName',
                                   'ShipTo.Name',
                                   'ShipTo.Address1',
                                   'CustomerIdentifier.Name'])

gp_receiver_info_nd = gp_acoustics.drop_duplicates(['ShipTo.CompanyName',
               'ShipTo.Name',
               'ShipTo.Address1',
               'CustomerIdentifier.Name'])

# %%
# Create Dictionaries from Invoice and Extensiv Tables to compare

idn_receiver_entry = {}

for i, row in invoice_data_null2.iterrows():

    idn_receiver_entry[i] = {'Receiver Address': row['Receiver Address'],
                        'Receiver Company': row['Receiver Company'],
                        'Receiver Name': row['Receiver Name'],
                        'Tracking #': row['Tracking #']}

# Create AMT Receiver Info dictionary
  
amt_receiver_entry = dict()

for i, row in amt_receiver_info_nd.iterrows():
    
    amt_receiver_entry[i] = {'Receiver Address': row['ShipTo.Address1'],
                                      'Receiver Company': row['ShipTo.CompanyName'],
                                      'Receiver Name': row['ShipTo.Name'],
                                      'Customer Identifier': row['CustomerIdentifier.Name']}
    

# Create GP Acoustics Receiver Info dictionary

gp_receiver_entry = dict()

for i, row in gp_receiver_info_nd.iterrows():
    
    gp_receiver_entry[i] = {'Receiver Address': row['ShipTo.Address1'],
                                      'Receiver Company': row['ShipTo.CompanyName'],
                                      'Receiver Name': row['ShipTo.Name'],
                                      'Customer Identifier': row['CustomerIdentifier.Name']}

# %%
def compare_receiver_info(fedex_receiver_info, ext_receiver_info):

    #! Should the combinations of Receiver Information be exact 'And' or 'Or'
    match_entry = dict()
    match_lst = list()

    for i in fedex_receiver_info:

        for e in ext_receiver_info:

            if fedex_receiver_info[i]['Receiver Address'] == ext_receiver_info[e]['Receiver Address'] or \
                fedex_receiver_info[i]['Receiver Name'] == ext_receiver_info[e]['Receiver Name'] or \
                fedex_receiver_info[i]['Receiver Company'] == ext_receiver_info[e]['Receiver Company']:

                match_entry = {'Address': fedex_receiver_info[i]['Receiver Address'],
                            'Name': fedex_receiver_info[i]['Receiver Name'],
                            'Company': fedex_receiver_info[i]['Receiver Company'],
                            'Customer': ext_receiver_info[e]['Customer Identifier']}
                
                if match_entry not in match_lst:
                    match_lst.append(match_entry)

    if match_lst:
        return match_lst
    else:
        print('No Match')

# %%
compare_receiver_info(idn_receiver_entry, gp_receiver_entry)
# Out:
# [{'Address': '13 MONMOUTH ST',
#   'Name': 'RELIC MUSIC LLC',
#   'Company': 'RELIC MUSIC LLC',
#   'Customer': 'GP Acoustics'},
#  {'Address': '5479 PERRY DR',
#   'Name': 'ISP TECHNOLOGIES LLC',
#   'Company': 'ISP TECHNOLOGIES LLC',
#   'Customer': 'GP Acoustics'},
#  {'Address': '380 LOG CANOE CIR',
#   'Name': 'PRS GUITARS',
#   'Company': 'PRS GUITARS',
#   'Customer': 'GP Acoustics'},
#  {'Address': '8 THORNTON RD',
#   'Name': 'MUSICAL FULFILMENT SERVICES',
#   'Company': 'MUSICAL FULFILMENT SERVICES',
#   'Customer': 'GP Acoustics'},
#  {'Address': '28 SUNDANCE CIR',
#   'Name': 'ATLAS CUSTOM CABINETS',
#   'Company': 'ATLAS CUSTOM CABINETS',
#   'Customer': 'GP Acoustics'},
#  {'Address': '180 CARPENTER AVE',
#   'Name': 'ALTO MUSIC',
#   'Company': 'ALTO MUSIC',
#   'Customer': 'GP Acoustics'},
#  {'Address': '71 STEEP RD',
#   'Name': 'STEVEN MILLER',
#   'Company': 'STEVEN MILLER',
#   'Customer': 'GP Acoustics'},
#  {'Address': '7091 NW 51ST ST',
#   'Name': 'MIAMI PARTS IMPORT,INC',
#   'Company': 'MIAMI PARTS IMPORT,INC',
#   'Customer': 'GP Acoustics'},
#  {'Address': '403 S H ST',
#   'Name': 'ADI TEJADA',
#   'Company': 'ADI TEJADA',
#   'Customer': 'GP Acoustics'},
#  {'Address': '2160 HILTON DR',
#   'Name': 'DANLEY SOUND LAB',
#   'Company': 'DANLEY SOUND LAB',
#   'Customer': 'GP Acoustics'},
#  {'Address': '1229 TRUMAN RD',
#   'Name': 'PAOLO GREGOLETTO',
#   'Company': 'PAOLO GREGOLETTO',
#   'Customer': 'GP Acoustics'}]

# %% [markdown]
# # MISC
