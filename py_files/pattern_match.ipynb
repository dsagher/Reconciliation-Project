# %%
import pandas as pd
import re as re
import numpy as np

from processing import invoice_data, qbo, whill, gp_acoustics, amt

pd.set_option('display.max_columns', 500)

# %% [markdown]
# ## **Invoice Data** <-> **QBO**
#
# ### - Compare **Invoice Data** [`Customer PO #`] to **QBO** [`Display_Name`]

# %%
def compare_qbo(qbo: pd.DataFrame, invoice_data: pd.DataFrame) -> pd.DataFrame:
    """
    Function: Compares FedEx invoice with QuickBooks via keys 'Customer PO #' and 'Display_Name'
    Input: Original QuickBooks and FedEx Invoice file
    Output: Pandas DataFrame with values not found in QuickBooks
    """

    # ? is 'Display_Name' the only key to compare against?

    qbo_found = pd.merge(
        qbo, invoice_data, right_on="Customer PO #", left_on="Display_Name", how="inner", suffixes=['_qbo','_invoice_data']
    )

    lst = set()
    for i in invoice_data["Customer PO #"]:
        if i not in list(qbo_found["Display_Name"].unique()):
            lst.add(i)

    qbo_not_found = pd.DataFrame()
    qbo_not_found["Customer PO #"] = pd.DataFrame(lst)
    qbo_not_found = qbo_not_found.merge(
        invoice_data,
        on="Customer PO #",
        how="left",
    )
    return qbo_found, qbo_not_found

# %%
# Run 
qbo_found, qbo_not_found = compare_qbo(qbo, invoice_data)

# %%
# Test
print(f"PO's in QBO: {len(qbo_found['Customer PO #'].unique())}")
# Out:
# PO's in QBO: 6

# %%
# Test
len(qbo_not_found['Customer PO #'].unique())
print(f"PO's in QBO: {len(qbo_not_found['Customer PO #'].unique())}")
# Out:
# PO's in QBO: 84

# %% [markdown]
# ## **Invoice Data** [`Reference`] <-> **Extensiv** [`Reference`]
#
# ### - For all **Invoice Data** [`Customer PO #`] not in **QBO** [`Display Name`]

# %%
def reg_tokenizer(value):
    
    # Add pattern tokens to FedEx invoice table in a new column called "Reference"
    with_letters = re.sub(r"[a-zA-Z]+", r"\\w+", str(value))
    with_numbers = re.sub(r"\d+", r"\\d+", with_letters)
    with_spaces = re.sub(r"\s+", r"\\s+", with_numbers)

    final = re.compile(with_spaces)

    return final

# %%
# Run it

invoice_data['Pattern'] = invoice_data['Reference'].apply(reg_tokenizer)

# %%
def find_extensiv_reference_columns(extensiv_table: pd.DataFrame, invoice_data_w_patterns: pd.DataFrame) -> dict:  # fmt: skip
    """
    Function: Finds all of the columns in the Extensiv table that match each 'Reference' in FedEx Invoice not in QBO
    Input: Extensiv DataFrame, FedEx Invoice DataFrame w/ added 'Pattern' column
    Ouput: Dictionary {'match_lst': list of Extensiv columns that match 'Reference' pattern,
                       'Total Charges': Charges associated with that 'Reference' in FedEx Invoice,
                       'Tracking #': Tracking number associated with that 'Reference' in FedEx Invoice}
    Notes: May not need Total Charges and Tracking # in the end
    """

    def find_col_match(extensiv_table: pd.DataFrame, ref_pattern: pd.Series) -> list:
        """
        Function: Subfunction to iterate through each of the patterns in FedEx Invoice
        Input: Extensiv DataFrame, FedEx Reference patterns as a Series in a for loop
        Ouput: List of columns that match given Reference pattern
        """
        col_lst = set()

        for col in extensiv_table.columns:

            for value in extensiv_table[col][:25]:

                if re.fullmatch(ref_pattern, str(value)):

                    col_lst.add(col.strip())

        if col_lst:
            return col_lst
        
    match_dct = dict()
    suffix = 0

    for i, v in enumerate(invoice_data_w_patterns["Reference"]):

        if i != 0 and v == invoice_data_w_patterns["Reference"][i - 1]:

            suffix += 1
            v = f"{v}-s{suffix}"

        elif i != 0 and v != invoice_data_w_patterns["Reference"][i - 1]:
            suffix = 0
        else:
            continue

        match_lst = find_col_match(
            extensiv_table, invoice_data_w_patterns["Pattern"][i]
        )

        if match_lst is not None and not pd.isna(v):

            match_dct[v] = {
                "match_lst": match_lst,
                "Tracking #": (invoice_data_w_patterns["Tracking #"][i]),
            }

    return match_dct

# %% [markdown]
# ### - Find Extensiv Reference Columns

# %%
gp_reference_columns = find_extensiv_reference_columns(gp_acoustics, qbo_not_found)
amt_reference_columns = find_extensiv_reference_columns(amt, qbo_not_found)
whill_reference_columns = find_extensiv_reference_columns(whill, qbo_not_found)

# %%
# VSCode Version of this Code

def find_value_match(extensiv_table: pd.DataFrame, reference_matches: dict) -> pd.DataFrame:

    match_lst = list()

    for reference in reference_matches:
        
        matches = reference_matches[reference]["match_lst"]
        tracking_number = reference_matches[reference]["Tracking #"]

        for col in extensiv_table[list[matches]]:

                for i, val in enumerate(extensiv_table[col]):

                    base_reference = re.sub(r"-s\d+$", "", str(reference))

                    if val == reference or val == base_reference:
    
                            match_entry = {
                                "Reference": base_reference,
                                "Name": extensiv_table["CustomerIdentifier.Name"][i],
                                "Column": col,
                                "Tracking #": tracking_number,
                            }

                            if match_entry not in match_lst:
                                match_lst.append(match_entry)

    
    return match_lst

# %%
gp_reference_matches = find_value_match(gp_acoustics,gp_reference_columns)
amt_reference_matches = find_value_match(amt,amt_reference_columns)
whill_reference_matches = find_value_match(whill,gp_reference_columns)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 gp_reference_matches = find_value_match(gp_acoustics,gp_reference_columns)
#
# Cell In[63], line 29, in find_value_match(extensiv_table, reference_matches)
#      21                         match_entry = {
#      22                             "Reference": base_reference,
#      23                             "Name": extensiv_table["CustomerIdentifier.Name"][i],
#      24                             "Column": col,
#      25                             "Tracking #": tracking_number,
#      26                         }
#      28                         if match_entry['Tracking #'] not in match_lst:
# ---> 29                             match_lst.append(match_entry)
#      32 return match_lst
#
# KeyboardInterrupt:

# %%
gp_reference_matches
# Out:
# [{'Reference': '15116',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Tracking #': 281752495934},
#  {'Reference': '10558',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Tracking #': 280881667358},
#  {'Reference': 'GP Acoustics',
#   'Name': 'GP Acoustics',
#   'Column': 'CustomerIdentifier.Name',
#   'Tracking #': 418132348770},
#  {'Reference': 'GP Acoustics',
#   'Name': 'GP Acoustics',
#   'Column': 'ShipTo.CompanyName',
#   'Tracking #': 418132348770},
#  {'Reference': 'GP Acoustics',
#   'Name': 'GP Acoustics',
#   'Column': 'ShipTo.Name',
#   'Tracking #': 418132348770},
#  {'Reference': 'GP Acoustics',
#   'Name': 'GP Acoustics',
#   'Column': 'CustomerIdentifier.Name',
#   'Tracking #': 418132348758},
#  {'Reference': 'GP Acoustics',
#   'Name': 'GP Acoustics',
#   'Column': 'ShipTo.CompanyName',
#   'Tracking #': 418132348758},
#  {'Reference': 'GP Acoustics',
#   'Name': 'GP Acoustics',
#   'Column': 'ShipTo.Name',
#   'Tracking #': 418132348758},
#  {'Reference': 'GP Acoustics',
#   'Name': 'GP Acoustics',
#   'Column': 'CustomerIdentifier.Name',
#   'Tracking #': 418132348769},
#  {'Reference': 'GP Acoustics',
#   'Name': 'GP Acoustics',
#   'Column': 'ShipTo.CompanyName',
#   'Tracking #': 418132348769},
#  {'Reference': 'GP Acoustics',
#   'Name': 'GP Acoustics',
#   'Column': 'ShipTo.Name',
#   'Tracking #': 418132348769},
#  {'Reference': 'GP Acoustics',
#   'Name': 'GP Acoustics',
#   'Column': 'CustomerIdentifier.Name',
#   'Tracking #': 418132348747},
#  {'Reference': 'GP Acoustics',
#   'Name': 'GP Acoustics',
#   'Column': 'ShipTo.CompanyName',
#   'Tracking #': 418132348747},
#  {'Reference': 'GP Acoustics',
#   'Name': 'GP Acoustics',
#   'Column': 'ShipTo.Name',
#   'Tracking #': 418132348747},
#  {'Reference': '10569',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Tracking #': 280881789594},
#  {'Reference': '10567',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Tracking #': 280882052528},
#  {'Reference': '10562',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Tracking #': 280881473027},
#  {'Reference': '14743',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Tracking #': 281567086557},
#  {'Reference': '14371',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Tracking #': 281397637770},
#  {'Reference': '13158',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Tracking #': 281058966643},
#  {'Reference': '10557',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Tracking #': 280881846057},
#  {'Reference': '10548',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Tracking #': 280881319542},
#  {'Reference': '11934',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Tracking #': 280986974282},
#  {'Reference': '10565',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Tracking #': 280882160702},
#  {'Reference': '10559',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Tracking #': 280882098840},
#  {'Reference': '10555',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Tracking #': 280881370665},
#  {'Reference': '10566',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Tracking #': 280881955477},
#  {'Reference': '11396',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Tracking #': 280807219242},
#  {'Reference': '10561',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Tracking #': 280881613185},
#  {'Reference': '13390',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Tracking #': 281142406523},
#  {'Reference': '13157',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Tracking #': 281058904347},
#  {'Reference': '11653',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Tracking #': 280887141570},
#  {'Reference': '13700',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Tracking #': 281249653359},
#  {'Reference': '10554',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Tracking #': 280881245477},
#  {'Reference': '10556',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Tracking #': 280881537650},
#  {'Reference': '11844',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Tracking #': 280986894281},
#  {'Reference': '13730',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Tracking #': 281241623171},
#  {'Reference': '11912',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Tracking #': 280986780422},
#  {'Reference': '13903',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Tracking #': 281242712302},
#  {'Reference': '13765',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Tracking #': 281248581945},
#  {'Reference': '13765',
#   'Name': 'GP Acoustics',
#   'Column': 'Packages.CartonId',
#   'Tracking #': 281248581945},
#  {'Reference': '10560',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Tracking #': 280881903399},
#  {'Reference': '11391',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Tracking #': 280766989314},
#  {'Reference': '11523',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Tracking #': 280791161446},
#  {'Reference': '10564',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Tracking #': 280882000233},
#  {'Reference': '11397',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Tracking #': 280768308100},
#  {'Reference': '10563',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Tracking #': 280881729544}]

# %%
def create_extensiv_receiver_info(extensiv_table: pd.DataFrame) -> dict:

    extensiv_receiver_info = extensiv_table[
        [
            "ShipTo.CompanyName",
            "ShipTo.Name",
            "ShipTo.Address1",
            "CustomerIdentifier.Name",
        ]
    ]

    extensiv_receiver_info_nd = extensiv_receiver_info.drop_duplicates(
        [
            "ShipTo.CompanyName",
            "ShipTo.Name",
            "ShipTo.Address1",
            "CustomerIdentifier.Name",
        ]
    )

    extensiv_receiver_dct = dict()

    for i, row in extensiv_receiver_info_nd.iterrows():

        extensiv_receiver_dct[i] = {
            "Receiver Address": row["ShipTo.Address1"],
            "Receiver Company": row["ShipTo.CompanyName"],
            "Receiver Name": row["ShipTo.Name"],
            "Customer Identifier": row["CustomerIdentifier.Name"],
        }

    return extensiv_receiver_dct


def create_invoice_data_receiver_info(invoice_data: pd.DataFrame) -> dict:  # fmt: skip

    invoice_data_dct = {}

    for i, row in invoice_data.iterrows():

        invoice_data_dct[i] = {
            "Receiver Address": row["Receiver Address"],
            "Receiver Company": row["Receiver Company"],
            "Receiver Name": row["Receiver Name"],
            "Tracking #": row["Tracking #"],
        }

    return invoice_data_dct

def compare_receiver_info(invoice_data_receiver_info: dict, extensiv_receiver_info: dict) -> list:  # fmt: skip

    match_entry = dict()
    match_lst = list()

    for i in invoice_data_receiver_info:

        for e in extensiv_receiver_info:

            if (
                invoice_data_receiver_info[i]["Receiver Address"]
                == extensiv_receiver_info[e]["Receiver Address"]
                or invoice_data_receiver_info[i]["Receiver Name"]
                == extensiv_receiver_info[e]["Receiver Name"]
                or invoice_data_receiver_info[i]["Receiver Company"]
                == extensiv_receiver_info[e]["Receiver Company"]
            ):

                match_entry = {
                    "Address": invoice_data_receiver_info[i]["Receiver Address"],
                    "Name": invoice_data_receiver_info[i]["Receiver Name"],
                    "Company": invoice_data_receiver_info[i]["Receiver Company"],
                    "Customer": extensiv_receiver_info[e]["Customer Identifier"],
                }

                if match_entry not in match_lst:
                    match_lst.append(match_entry)
    if match_lst:
        return match_lst

# %%
gp_receiver_info = create_extensiv_receiver_info(gp_acoustics)
amt_receiver_info = create_extensiv_receiver_info(amt)
whill_receiver_info = create_extensiv_receiver_info(whill)
invoice_data_receiver_info = create_invoice_data_receiver_info(invoice_data)

# %%
def make_final_df(reference_matches, receiver_matches, invoice_data_not_qbo):

    try:

        final_matches_lst = []
        final_matches_lst.extend(reference_matches)
        final_matches_lst.extend(receiver_matches)
        
        for i, row in invoice_data_not_qbo.iterrows():

            for dct in final_matches_lst:
                

                if "Reference" in dct and dct["Reference"] == row["Reference"]:
                    invoice_data_not_qbo.loc[i, "Customer PO #"] = dct["Name"]
                elif "Address" in dct and dct["Address"] == row["Receiver Address"]:
                    invoice_data_not_qbo.loc[i, "Customer PO #"] = dct["Customer"]
                elif "Name" in dct and dct["Name"] == row["Receiver Name"]:
                    invoice_data_not_qbo.loc[i, "Customer PO #"] = dct["Customer"]
                elif "Company" in dct and dct["Company"] == row["Receiver Company"]:
                    invoice_data_not_qbo.loc[i, "Customer PO #"] = dct["Customer"]
                elif "Reference" in dct:
                    try:
                        dct["Reference"] = int(dct["Reference"])
                    except ValueError:
                        pass
    
    except TypeError:
        pass


    return invoice_data_not_qbo

# %%
gp_receiver_matches = compare_receiver_info(
    invoice_data_receiver_info, gp_receiver_info
)
amt_receiver_matches = compare_receiver_info(
    invoice_data_receiver_info, amt_receiver_info
)
whill_receiver_matches = compare_receiver_info(
    invoice_data_receiver_info, whill_receiver_info
)
final_df = make_final_df(
    gp_reference_matches, gp_receiver_matches, qbo_not_found
)
final_df = make_final_df(
    amt_reference_matches, amt_receiver_matches, qbo_not_found
)
final_df = make_final_df(
    whill_reference_matches, whill_receiver_matches, qbo_not_found
)

# del final_df["Pattern"]

# %%
gp_reference_matches
# Out:
# [{'Reference': 10554,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 6.54,
#   'Tracking #': 280881245477},
#  {'Reference': 10560,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 8.21,
#   'Tracking #': 280881903399},
#  {'Reference': 11523,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 19.93,
#   'Tracking #': 280791161446},
#  {'Reference': 10556,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 4.92,
#   'Tracking #': 280881537650},
#  {'Reference': 11934,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 10.85,
#   'Tracking #': 280986974282},
#  {'Reference': 10564,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 5.18,
#   'Tracking #': 280882000233},
#  {'Reference': 11912,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 8.54,
#   'Tracking #': 280986780422},
#  {'Reference': 10566,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 9.56,
#   'Tracking #': 280881955477},
#  {'Reference': 11397,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 9.56,
#   'Tracking #': 280768308100},
#  {'Reference': 13157,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 9.39,
#   'Tracking #': 281058904347},
#  {'Reference': 10558,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 4.92,
#   'Tracking #': 280881667358},
#  {'Reference': 11844,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 7.7,
#   'Tracking #': 280986894281},
#  {'Reference': 11391,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 9.56,
#   'Tracking #': 280766989314},
#  {'Reference': 11653,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 30.42,
#   'Tracking #': 280887141570},
#  {'Reference': 10555,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 5.85,
#   'Tracking #': 280881370665},
#  {'Reference': 13158,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 24.42,
#   'Tracking #': 281058966643},
#  {'Reference': 10548,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 4.85,
#   'Tracking #': 280881319542},
#  {'Reference': 10565,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 14.17,
#   'Tracking #': 280882160702},
#  {'Reference': 11396,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 9.56,
#   'Tracking #': 280807219242},
#  {'Reference': 13903,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 4.85,
#   'Tracking #': 281242712302},
#  {'Reference': 10561,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 7.47,
#   'Tracking #': 280881613185},
#  {'Reference': 14371,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 9.62,
#   'Tracking #': 281397637770},
#  {'Reference': 10563,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 5.56,
#   'Tracking #': 280881729544},
#  {'Reference': 13390,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 23.69,
#   'Tracking #': 281142406523},
#  {'Reference': 15116,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 5.17,
#   'Tracking #': 281752495934},
#  {'Reference': 10569,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 5.91,
#   'Tracking #': 280881789594},
#  {'Reference': 13765,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 17.18,
#   'Tracking #': 281248581945},
#  {'Reference': 13765,
#   'Name': 'GP Acoustics',
#   'Column': 'Packages.CartonId',
#   'Total Charges': 17.18,
#   'Tracking #': 281248581945},
#  {'Reference': 10567,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 9.56,
#   'Tracking #': 280882052528},
#  {'Reference': 10557,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 5.55,
#   'Tracking #': 280881846057},
#  {'Reference': 10562,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 10.63,
#   'Tracking #': 280881473027},
#  {'Reference': 'GP Acoustics',
#   'Name': 'GP Acoustics',
#   'Column': 'CustomerIdentifier.Name',
#   'Total Charges': 11.9,
#   'Tracking #': 418132348770},
#  {'Reference': 'GP Acoustics',
#   'Name': 'GP Acoustics',
#   'Column': 'ShipTo.CompanyName',
#   'Total Charges': 11.9,
#   'Tracking #': 418132348770},
#  {'Reference': 'GP Acoustics',
#   'Name': 'GP Acoustics',
#   'Column': 'ShipTo.Name',
#   'Total Charges': 11.9,
#   'Tracking #': 418132348770},
#  {'Reference': 'GP Acoustics',
#   'Name': 'GP Acoustics',
#   'Column': 'CustomerIdentifier.Name',
#   'Total Charges': 11.9,
#   'Tracking #': 418132348758},
#  {'Reference': 'GP Acoustics',
#   'Name': 'GP Acoustics',
#   'Column': 'ShipTo.CompanyName',
#   'Total Charges': 11.9,
#   'Tracking #': 418132348758},
#  {'Reference': 'GP Acoustics',
#   'Name': 'GP Acoustics',
#   'Column': 'ShipTo.Name',
#   'Total Charges': 11.9,
#   'Tracking #': 418132348758},
#  {'Reference': 'GP Acoustics',
#   'Name': 'GP Acoustics',
#   'Column': 'CustomerIdentifier.Name',
#   'Total Charges': 11.9,
#   'Tracking #': 418132348769},
#  {'Reference': 'GP Acoustics',
#   'Name': 'GP Acoustics',
#   'Column': 'ShipTo.CompanyName',
#   'Total Charges': 11.9,
#   'Tracking #': 418132348769},
#  {'Reference': 'GP Acoustics',
#   'Name': 'GP Acoustics',
#   'Column': 'ShipTo.Name',
#   'Total Charges': 11.9,
#   'Tracking #': 418132348769},
#  {'Reference': 'GP Acoustics',
#   'Name': 'GP Acoustics',
#   'Column': 'CustomerIdentifier.Name',
#   'Total Charges': 11.9,
#   'Tracking #': 418132348747},
#  {'Reference': 'GP Acoustics',
#   'Name': 'GP Acoustics',
#   'Column': 'ShipTo.CompanyName',
#   'Total Charges': 11.9,
#   'Tracking #': 418132348747},
#  {'Reference': 'GP Acoustics',
#   'Name': 'GP Acoustics',
#   'Column': 'ShipTo.Name',
#   'Total Charges': 11.9,
#   'Tracking #': 418132348747},
#  {'Reference': 13730,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 22.44,
#   'Tracking #': 281241623171},
#  {'Reference': 14743,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 7.29,
#   'Tracking #': 281567086557},
#  {'Reference': 13700,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 15.81,
#   'Tracking #': 281249653359},
#  {'Reference': 10559,
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': 12.1,
#   'Tracking #': 280882098840}]

# %%
final_df[final_df['Customer PO #'] == 'GP Acoustics']
# Out:
#      Customer PO #    Shipper #    Invoice # Invoice Date  Invoice Amount  \
# 67    GP Acoustics  693070511.0  866891360.0   2024-11-01        24182.11
# 694   GP Acoustics  693070511.0  866891360.0   2024-11-01        24182.11
# 1202  GP Acoustics  693070511.0  866891360.0   2024-11-01        24182.11
# 1204  GP Acoustics  693070511.0  866891361.0   2024-11-01        21136.17
# 1240  GP Acoustics  693070511.0  866891361.0   2024-11-01        21136.17
# 1241  GP Acoustics  693070511.0  866891361.0   2024-11-01        21136.17
# 1242  GP Acoustics  693070511.0  867618863.0   2024-11-08        29866.52
# 1243  GP Acoustics  693070511.0  866891361.0   2024-11-01        21136.17
# 1246  GP Acoustics  693070511.0  866891362.0   2024-11-01        37778.60
# 1247  GP Acoustics  693070511.0  867618864.0   2024-11-08        25739.62
# 1248  GP Acoustics  693070511.0  866891360.0   2024-11-01        24182.11
# 1249  GP Acoustics  693070511.0  867618863.0   2024-11-08        29866.52
# 1252  GP Acoustics  693070511.0  866891362.0   2024-11-01        37778.60
# 1253  GP Acoustics  693070511.0  866891362.0   2024-11-01        37778.60
# 1254  GP Acoustics  693070511.0  866891360.0   2024-11-01        24182.11
# 1255  GP Acoustics  693070511.0  866891361.0   2024-11-01        21136.17
# 1256  GP Acoustics  693070511.0  866891361.0   2024-11-01        21136.17
# 1257  GP Acoustics  693070511.0  866891361.0   2024-11-01        21136.17
# 1258  GP Acoustics  693070511.0  866891361.0   2024-11-01        21136.17
# 1260  GP Acoustics  693070511.0  866891360.0   2024-11-01        24182.11
# 1261  GP Acoustics  693070511.0  867618864.0   2024-11-08        25739.62
# 1262  GP Acoustics  693070511.0  867618864.0   2024-11-08        25739.62
# 1263  GP Acoustics  693070511.0  866891360.0   2024-11-01        24182.11
# 1265  GP Acoustics  693070511.0  866891361.0   2024-11-01        21136.17
# 1625  GP Acoustics  693070511.0  866891360.0   2024-11-01        24182.11
# 1742  GP Acoustics  693070511.0  867618865.0   2024-11-08        18523.17
# 1746  GP Acoustics  693070511.0  866891360.0   2024-11-01        24182.11
# 1747  GP Acoustics  693070511.0  868389946.0   2024-11-15        27353.46
# 1749  GP Acoustics  693070511.0  866891360.0   2024-11-01        24182.11
# 1753  GP Acoustics  693070511.0  867618864.0   2024-11-08        25739.62
# 1754  GP Acoustics  693070511.0  867618864.0   2024-11-08        25739.62
# 1755  GP Acoustics  693070511.0  869086369.0   2024-11-22        25820.77
# 1756  GP Acoustics  693070511.0  866891361.0   2024-11-01        21136.17
# 1757  GP Acoustics  693070511.0  867618865.0   2024-11-08        18523.17
# 1758  GP Acoustics  693070511.0  867618865.0   2024-11-08        18523.17
# 1759  GP Acoustics  693070511.0  867618865.0   2024-11-08        18523.17
# 1760  GP Acoustics  693070511.0  867618865.0   2024-11-08        18523.17
# 1763  GP Acoustics  693070511.0  866891361.0   2024-11-01        21136.17
# 1765  GP Acoustics  693070511.0  866891361.0   2024-11-01        21136.17
# 1766  GP Acoustics  693070511.0  866891360.0   2024-11-01        24182.11
# 1767  GP Acoustics  693070511.0  866891361.0   2024-11-01        21136.17
# 1879  GP Acoustics  693070511.0  867618863.0   2024-11-08        29866.52
# 1880  GP Acoustics  693070511.0  867618863.0   2024-11-08        29866.52
# 1881  GP Acoustics  693070511.0  867618863.0   2024-11-08        29866.52
# 1882  GP Acoustics  693070511.0  867618863.0   2024-11-08        29866.52
# 1883  GP Acoustics  693070511.0  867618865.0   2024-11-08        18523.17
# 1884  GP Acoustics  693070511.0  867618865.0   2024-11-08        18523.17
# 1885  GP Acoustics  693070511.0  867618865.0   2024-11-08        18523.17
# 1886  GP Acoustics  693070511.0  867618865.0   2024-11-08        18523.17
#
#
#             Receiver Address         Receiver City Receiver State  \
# 67        12914 STATELINE RD          OLIVE BRANCH             MS
# 694           450 MAESTRO DR                  RENO             NV
# 1202              403 S H ST                LOMPOC             CA
# 1204          1040 N WYNN RD                OREGON             OH
# 1240       1809 S VASSAR AVE          INDEPENDENCE             MO
# 1241           8 THORNTON RD               OAKLAND             NJ
# 1242           407 GETTY AVE               CLIFTON             NJ
# 1243           8 THORNTON RD               OAKLAND             NJ
# 1246          13 MONMOUTH ST              RED BANK             NJ
# 1247   137 WORTH BEVERAGE DR                BURGAW             NC
# 1248          1040 N WYNN RD                OREGON             OH
# 1249           407 GETTY AVE               CLIFTON             NJ
# 1252       180 CARPENTER AVE            MIDDLETOWN             NY
# 1253       180 CARPENTER AVE            MIDDLETOWN             NY
# 1254          1229 TRUMAN RD               ORLANDO             FL
# 1255          1229 TRUMAN RD               ORLANDO             FL
# 1256          1229 TRUMAN RD               ORLANDO             FL
# 1257          1229 TRUMAN RD               ORLANDO             FL
# 1258          1229 TRUMAN RD               ORLANDO             FL
# 1260      12914 STATELINE RD          OLIVE BRANCH             MS
# 1261        11411 VANOWEN ST       NORTH HOLLYWOOD             CA
# 1262        11411 VANOWEN ST       NORTH HOLLYWOOD             CA
# 1263      12914 STATELINE RD          OLIVE BRANCH             MS
# 1265           8 THORNTON RD               OAKLAND             NJ
# 1625         7091 NW 51ST ST                 MIAMI             FL
# 1742           5479 PERRY DR             WATERFORD             MI
# 1746          1040 N WYNN RD                OREGON             OH
# 1747          2160 HILTON DR           GAINESVILLE             GA
# 1749          1040 N WYNN RD                OREGON             OH
# 1753         28 SUNDANCE CIR             NEDERLAND             CO
# 1754         28 SUNDANCE CIR             NEDERLAND             CO
# 1755           200 WILSON ST  PORT JEFFERSON STATI             NY
# 1756          450 MAESTRO DR                  RENO             NV
# 1757      1251 W HARDING WAY              STOCKTON             CA
# 1758      1251 W HARDING WAY              STOCKTON             CA
# 1759      1251 W HARDING WAY              STOCKTON             CA
# 1760      1251 W HARDING WAY              STOCKTON             CA
# 1763           8 THORNTON RD               OAKLAND             NJ
# 1765          450 MAESTRO DR                  RENO             NV
# 1766      12914 STATELINE RD          OLIVE BRANCH             MS
# 1767      12914 STATELINE RD          OLIVE BRANCH             MS
# 1879           5479 PERRY DR             WATERFORD             MI
# 1880           5479 PERRY DR             WATERFORD             MI
# 1881           5479 PERRY DR             WATERFORD             MI
# 1882           5479 PERRY DR             WATERFORD             MI
# 1883       380 LOG CANOE CIR          STEVENSVILLE             MD
# 1884       380 LOG CANOE CIR          STEVENSVILLE             MD
# 1885       380 LOG CANOE CIR          STEVENSVILLE             MD
# 1886       380 LOG CANOE CIR          STEVENSVILLE             MD
# 1887  5022 HARTLEY PEAVEY DR              MERIDIAN             MS
# 1893             71 STEEP RD         SOUTH WINDSOR             CT
# 2348           8 THORNTON RD               OAKLAND             NJ
#
#       Receiver Postal Code Receiver Country  Declared Value  Customs Value  \
# 67             386544017.0               US             0.0            0.0
# 694            895111294.0               US             0.0            0.0
# 1202           934367812.0               US             0.0            0.0
# 1204           436161430.0               US             0.0            0.0
# 1240           640524053.0               US             0.0            0.0
# 1241            74363116.0               US             0.0            0.0
