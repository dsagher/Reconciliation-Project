# %%
import pandas as pd
import numpy as np
import re as re

pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows',100)

# %%
# Take in Excel

itemized = pd.read_excel("C:/Users/danie/OneDrive/Projects/fedex_reconciliation/Invoice_data.xlsx", header=2, sheet_name=0)
invoice_data = pd.read_excel("C:/Users/danie/OneDrive/Projects/fedex_reconciliation/Invoice_data.xlsx", sheet_name=1)
qbo = pd.read_excel("C:/Users/danie/OneDrive/Projects/fedex_reconciliation/QBO_customers(1).xlsx")
amt = pd.read_excel("C:/Users/danie/OneDrive/Projects/fedex_reconciliation/Exensiv.xlsx", sheet_name='AMT')
gp_acoustics = pd.read_excel("C:/Users/danie/OneDrive/Projects/fedex_reconciliation/Exensiv.xlsx", sheet_name='GPAcoustics')

# %% [markdown]
# # **Invoice Data** <-> **QBO**
#
# ## - Compare **Invoice Data** [`Customer PO #`] to **QBO** [`Display_Name`]

# %%
# Merge QuickBooks and FedEx to find shared values

#? Check if ['Display name'] is the only key to compare against

qbo_found = pd.merge(qbo, invoice_data, right_on='Customer PO #', left_on= 'Display_Name', how='inner')

# %%
# Number of PO's Found in QuickBooks

print(f'Unique Found POs: {len(qbo_found['Display_Name'].drop_duplicates())}',
      f'Total Found POs: {len(qbo_found)}', sep='\n')
# Out:
# Unique Found POs: 6
# Total Found POs: 2218

# %%
def compare_qbo(qbo: pd.DataFrame, invoice_data: pd.DataFrame) -> pd.DataFrame:
    """
    Function: Compares FedEx invoice with QuickBooks via keys 'Customer PO #' and 'Display_Name'
    Input: Original QuickBooks and FedEx Invoice file
    Output: Pandas DataFrame with values not found in QuickBooks
    """

    # ? is 'Display_Name' the only key to compare against?

    qbo_found = pd.merge(
        qbo, invoice_data, right_on="Customer PO #", left_on="Display_Name", how="inner"
    )

    lst = set()
    for i in invoice_data["Customer PO #"]:
        if i not in list(qbo_found["Display_Name"].unique()):
            lst.add(i)

    not_found = pd.DataFrame()
    not_found["Customer PO #"] = pd.DataFrame(lst)
    not_found = not_found.merge(
        invoice_data[
            [
                "Customer PO #",
                "Reference",
                "Reference 2",
                "Total Charges",
                "Receiver Name",
                "Receiver Company",
                "Receiver Address",
                "Tracking #",
            ]
        ],
        on="Customer PO #",
        how="left",
    )
    return not_found

# %% [markdown]
# ### - Add not found values to new table: `not_found`

# %%
# Add unique Customer PO's not found in quickbooks to a unique list

lst = set()
for i in invoice_data['Customer PO #']:
    if i not in list(qbo_found['Display_Name'].unique()):
        lst.add(i)

# %%
len(lst)
# Out:
# 84

# %%
not_found = pd.DataFrame()
not_found['Customer PO #'] = pd.DataFrame(lst)
not_found = not_found.merge(invoice_data,
                             on='Customer PO #', how='left')
not_found
# Out:
#                   Customer PO #  Shipper #  Invoice # Invoice Date  \
# 0     Nautical/Qoute/BottleNeck  693070511  867618863   2024-11-08
# 1            700670008/SD266463  693070511  866891361   2024-11-01
# 2             ARRCO-20424-00014  693070511  867618863   2024-11-08
# 3             ARRCO-20424-00014  693070511  867618863   2024-11-08
# 4             ARRCO-20424-00014  693070511  867618863   2024-11-08
# ...                         ...        ...        ...          ...
# 2750          ARRCO-20424-00016  693070511  869086366   2024-11-22
# 
# 1                  NaN  MUSICAL FULFILLMENT NV
# 2                  NaN           EMMALEE EVANS
# 3                  NaN              Kaley Sorg
# 4                  NaN          MS. LIVINGSTON
# ...                ...                     ...
# 2750               NaN            ESTEBAN SOSA
# 2751               NaN          COURTNEY SCOTT
# 2752               NaN         JENNIFER RECTOR
# 2753               NaN                     LOU
# 2754               NaN  MUSICAL FULFILLMENT OH
#
#                          Receiver Company                    Receiver Address  \
# 0                           Dome Printing                      2031 Dome Lane
# 1                  MUSICAL FULFILLMENT NV                      450 MAESTRO DR
# 2             U OF OK | KAPPA KAPPA GAMMA                      1212 W 4TH AVE
# 3       Ball State University (Tutor Ctr)  2000 W. University Ave North Quad,
# 4     GWINNETT COLLEGE (ROSWELL/SANDY SPR                 1455 OLD ALABAMA RD
# ...                                   ...                                 ...
# 2750                   BLAIR S KRANSON MD                   7320 WOODLAKE AVE
# 2751                     MIDWIFE COURTNEY                        1444 MAIN ST
# 2752     THE VILLAGE MIDWIFE BIRTH CENTER                         321 MAIN ST
# 2753                   SOUTHWEST MIDWIVES                        1 MERCADO ST
# 2754               MUSICAL FULFILLMENT OH                      1040 N WYNN RD
#
#      Receiver City Receiver State  Receiver Postal Code Receiver Country  \
# 0        MCCLELLAN             CA               95652.0               US
# 1             RENO             NV           895111294.0               US
# 2       STILLWATER             OK           740743147.0               US
# 3           Muncie             IN               47306.0               US
# 4          ROSWELL             GA           300762167.0               US
# ...            ...            ...                   ...              ...
# 2750    WEST HILLS             CA           913071496.0               US
# 2751        RAMONA             CA           920658106.0               US
# 2752  NEWPORT NEWS             VA           236013814.0               US
# 2753       DURANGO             CO           813017311.0               US
# 2754        OREGON             OH           436161430.0               US
#
#       Customer Dept. #  Customer Invoice #  Declared Value  Customs Value  \
# 0                  NaN                 NaN               0              0
# 1                  NaN                 NaN               0              0
# 2                  NaN                 NaN               0              0
# 3                  NaN                 NaN               0              0
# 4                  NaN                 NaN               0              0
# ...                ...                 ...             ...            ...
# 2750               NaN                 NaN               0              0
# 2751               NaN                 NaN               0              0
# 2752               NaN                 NaN               0              0
# 2753               NaN                 NaN               0              0
# 2754               NaN                 NaN               0              0
#
#       GL Code  Shipper Account Reference 2  Length  Width  Height Control #  \
# 0         NaN        693070511         NaN      14     10       6  ADVA4456
# 1         NaN        693070511         NaN      14     14      14  ADVA4452
# 2         NaN        693070511         NaN      14     13      10  ADVA4456
# 3         NaN        693070511         NaN      14     13      10  ADVA4456
# 4         NaN        693070511         NaN      14     13      10  ADVA4456
# ...       ...              ...         ...     ...    ...     ...       ...
# 2750      NaN        693070511         NaN      14     11      10  ADVA4472
# 2751      NaN        693070511         NaN      14     11      10  ADVA4472
# 2752      NaN        693070511         NaN      14     11      10  ADVA4472
# 2753      NaN        693070511         NaN      14     11      10  ADVA4472
# 2754      NaN        693070511         NaN      14     14      14  ADVA4452
#
#       Credit Reason  Published Amount  Discounted Amount  Residential   DAS  \
# 0               NaN             16.24             -11.75         0.00  0.00
# 1               NaN             20.95             -15.48         0.00  0.00
# 2               NaN             14.13              -9.64         0.00  0.00
# 3               NaN             15.62             -11.13         0.00  0.00
# 4               NaN             16.86             -12.37         0.00  0.00
# ...             ...               ...                ...          ...   ...
# 2750            NaN             27.28             -20.16         0.00  0.00
# 2751            NaN             27.28             -20.16         0.00  1.15
# 2752            NaN             27.28             -20.16         5.55  0.00
# 2753            NaN             24.22             -17.90         0.00  1.15
# 2754            NaN             17.43             -12.88         0.00  0.00
#
#       Fuel  Saturday Delivery  Add'd Handling  Misc. Charges   Client   \
# 0     0.36                  0             0.0           0.00  Nautical
# 1     0.44                  0             0.0           0.00  Nautical
# 2     0.36                  0             0.0           0.00  Nautical
# 3     0.36                  0             0.0           0.00  Nautical
# 4     0.36                  0             0.0           0.00  Nautical
# ...    ...                ...             ...            ...       ...
# 2750  0.58                  0             0.0           0.00  Nautical
# 2751  0.67                  0             0.0           0.00  Nautical
# 2752  1.05                  0             0.0           0.23  Nautical
# 2753  0.60                  0             0.0           0.00  Nautical
# 2754  0.37                  0             0.0           0.00  Nautical
#
#             Coding  Total Charges  Adjusted Amount  Audited Amount  \
# 0     59062/587120           4.85                0            4.85
# 1     59062/587120           5.91                0            5.91
# 2     59062/587120           4.85                0            4.85
# 3     59062/587120           4.85                0            4.85
# 4     59062/587120           4.85                0            4.85
# ...            ...            ...              ...             ...
# 2750  59062/587120           7.70                0            7.70
# 2751  59062/587120           8.94                0            8.94
# 2752  59062/587120          13.95                0           13.95
# 2753  59062/587120           8.07                0            8.07
# 2754  59062/587120           4.92                0            4.92
#
#        Service Packaging
# 0     Customer Packaging
# 1     Customer Packaging
# 2     Customer Packaging
# 3     Customer Packaging
# 4     Customer Packaging
# ...                  ...
# 2750  Customer Packaging
# 2751  Customer Packaging
# 2752  Customer Packaging
# 2753  Customer Packaging
# 2754  Customer Packaging
#
# [2755 rows x 60 columns]

# %%
def compare_qbo(qbo: pd.DataFrame, invoice_data: pd.DataFrame) -> pd.DataFrame:
    """
    Function: Compares FedEx invoice with QuickBooks via keys 'Customer PO #' and 'Display_Name'
    Input: Original QuickBooks and FedEx Invoice file
    Output: Pandas DataFrame with values not found in QuickBooks
    """

    # ? is 'Display_Name' the only key to compare against?

    qbo_found = pd.merge(
        qbo, invoice_data, right_on="Customer PO #", left_on="Display_Name", how="inner"
    )

    lst = set()
    for i in invoice_data["Customer PO #"]:
        if i not in list(qbo_found["Display_Name"].unique()):
            lst.add(i)

    not_found = pd.DataFrame()
    not_found["Customer PO #"] = pd.DataFrame(lst)
    not_found = not_found.merge(
        invoice_data[
            [
                "Customer PO #",
                "Reference",
                "Reference 2",
                "Total Charges",
                "Receiver Name",
                "Receiver Company",
                "Receiver Address",
                "Tracking #",
            ]
        ],
        on="Customer PO #",
        how="left",
    )
    return not_found

# %% [markdown]
# # **Invoice Data** [`Reference`] <-> **Extensiv** [`Reference`]
#
# ## - For all **Invoice Data** [`Customer PO #`] not in **QBO** [`Display Name`]

# %% [markdown]
# ### - Create RegEx token function

# %%
# Create Regex Tokens

def reg_tokenizer(value):

    '''
    Input: Value of each column in Reference and Reference 2
    Output: RegEx object
    '''

    with_letters = re.sub(r'[a-zA-Z]+',r'\\w+' , str(value))

    with_numbers = re.sub(r'\d+', r'\\d+', with_letters)

    with_spaces = re.sub(r'\s+', r'\\s+', with_numbers)

    final = re.compile(with_spaces)
    
    return final

# %%
# RegEx Test

for i in range(len(not_found['Customer PO #'])):

    test = reg_tokenizer(not_found['Customer PO #'][i])
    
    match = re.fullmatch(test, str(not_found['Customer PO #'][i]))
    
    # print(f'{test}, original: {not_found['Customer PO #'][i]}, match: {match.group(0)}')

# %% [markdown]
# ### - Add RegEx column to `not_found` with [Reference] patterns

# %%
# Add Pattern column

token_lst = []

for i in not_found['Reference']:
    token_lst.append(reg_tokenizer(i))

not_found['Pattern'] = token_lst

# %%
# Fedex columns with added Reference pattern

not_found
# Out:
#                   Customer PO #  Shipper #  Invoice # Invoice Date  \
# 0     Nautical/Qoute/BottleNeck  693070511  867618863   2024-11-08
# 1            700670008/SD266463  693070511  866891361   2024-11-01
# 2             ARRCO-20424-00014  693070511  867618863   2024-11-08
# 3             ARRCO-20424-00014  693070511  867618863   2024-11-08
# 4             ARRCO-20424-00014  693070511  867618863   2024-11-08
# ...                         ...        ...        ...          ...
# 2750          ARRCO-20424-00016  693070511  869086366   2024-11-22
# 2751          ARRCO-20424-00016  693070511  869086366   2024-11-22
# 2752          ARRCO-20424-00016  693070511  869086366   2024-11-22
# 2753          ARRCO-20424-00016  693070511  869086366   2024-11-22
# 2754         700670006/SD266461  693070511  866891360   2024-11-01
#
#       Invoice Amount    Tracking #  Ship Date Delivery Date Delivery Time  \
# 0           29866.52  418132348736 2024-10-23    2024-10-28      15:26:00
# 1           21136.17  280881789594 2024-10-21    2024-10-24      12:23:00
# 2           29866.52  419064408583 2024-10-25    2024-10-28      11:52:00
# 3           29866.52  419064415883 2024-10-25    2024-10-30      11:55:00
# 4           29866.52  419064415060 2024-10-25    2024-10-28      12:58:00
# ...              ...           ...        ...           ...           ...
# 2750        39212.48  416398396447 2024-11-05    2024-11-11      11:17:00
# 2751        39212.48  416398395999 2024-11-05    2024-11-12      12:17:00
# 2752        39212.48  416398394308 2024-11-05    2024-11-15      10:53:00
# 2753        39212.48  416398397075 2024-11-05    2024-11-11      12:26:00
# 2754        24182.11  280881667358 2024-10-21    2024-10-23      12:17:00
#
#      Service Level  Zone                    Reference Department Bill Option  \
# 0           Ground     7          BottleNecker Sample        NaN     Prepaid
# 1           Ground     6                        10569        NaN     Prepaid
# 2           Ground     3   Nautical/Arrived/OllyChews        NaN     Prepaid
# 3           Ground     4   Nautical/Arrived/OllyChews        NaN     Prepaid
# 4           Ground     5   Nautical/Arrived/OllyChews        NaN     Prepaid
# ...            ...   ...                          ...        ...         ...
# 2750        Ground     6  Nautical/Arrived/WaterWipes        NaN     Prepaid
# 2751        Ground     6  Nautical/Arrived/WaterWipes        NaN     Prepaid
# 2752        Ground     6  Nautical/Arrived/WaterWipes        NaN     Prepaid
# 2753        Ground     5  Nautical/Arrived/WaterWipes        NaN     Prepaid
# 2754        Ground     4                        10558        NaN     Prepaid
#
#       Piece Count  Actual Weight  Bill Weight  Cwt Weight  Ship Device  \
# 0             NaN            2.2            3         NaN          NaN
# 1             NaN           12.6           13         NaN          NaN
# 2             NaN            5.7            6         NaN          NaN
# 3             NaN            5.7            6         NaN          NaN
# 4             NaN            5.7            6         NaN          NaN
# ...           ...            ...          ...         ...          ...
# 2750          NaN           19.0           19         NaN          NaN
# 2751          NaN           18.6           19         NaN          NaN
# 2752          NaN           18.4           19         NaN          NaN
# 2753          NaN           19.1           20         NaN          NaN
# 2754          NaN           12.6           13         NaN          NaN
#
#               Shipper Name       Shipper Company    Shipper Address  \
# 0     Nautical Fulfillment  Nautical Fulfillment   16100 W 116th St
# 1        Nautical - Renner     Nautical - Renner  16100 W. 116th St
# 2             Jeff Flassig   Advantage Solutions   16000 W 116th st
# 3             Jeff Flassig   Advantage Solutions   16000 W 116th st
# 4             Jeff Flassig   Advantage Solutions   16000 W 116th st
# ...                    ...                   ...                ...
# 2750          Jeff Flassig   Advantage Solutions   16000 W 116th st
# 2751          Jeff Flassig   Advantage Solutions   16000 W 116th st
# 2752          Jeff Flassig   Advantage Solutions   16000 W 116th st
# 2753          Jeff Flassig   Advantage Solutions   16000 W 116th st
# 2754     Nautical - Renner     Nautical - Renner  16100 W. 116th St
#
#      Shipper City Shipper State  Shipper Postal Code Shipper Country  \
# 0          Lenexa            KS                66219              US
# 1          Lenexa            KS                66219              US
# 2          Lenexa            KS                66219              US
# 3          Lenexa            KS                66219              US
# 4          Lenexa            KS                66219              US
# ...           ...           ...                  ...             ...
# 2750       lenexa            KS                66219              US
# 2751       lenexa            KS                66219              US
# 2752       lenexa            KS                66219              US
# 2753       lenexa            KS                66219              US
# 2754       Lenexa            KS                66219              US
#
#       Receiver Account           Receiver Name  \
# 0                  NaN             Devon Davis
# 1                  NaN  MUSICAL FULFILLMENT NV
# 2                  NaN           EMMALEE EVANS
# 3                  NaN              Kaley Sorg
# 4                  NaN          MS. LIVINGSTON
# ...                ...                     ...
# 2750               NaN            ESTEBAN SOSA
# 2751               NaN          COURTNEY SCOTT
# 2752               NaN         JENNIFER RECTOR
# 2753               NaN                     LOU
# 2754               NaN  MUSICAL FULFILLMENT OH
#
#                          Receiver Company                    Receiver Address  \
# 0                           Dome Printing                      2031 Dome Lane
# 1                  MUSICAL FULFILLMENT NV                      450 MAESTRO DR
# 2             U OF OK | KAPPA KAPPA GAMMA                      1212 W 4TH AVE
# 3       Ball State University (Tutor Ctr)  2000 W. University Ave North Quad,
# 4     GWINNETT COLLEGE (ROSWELL/SANDY SPR                 1455 OLD ALABAMA RD
# ...                                   ...                                 ...
# 2750                   BLAIR S KRANSON MD                   7320 WOODLAKE AVE
# 2751                     MIDWIFE COURTNEY                        1444 MAIN ST
# 2752     THE VILLAGE MIDWIFE BIRTH CENTER                         321 MAIN ST
# 2753                   SOUTHWEST MIDWIVES                        1 MERCADO ST
# 2754               MUSICAL FULFILLMENT OH                      1040 N WYNN RD
#
#      Receiver City Receiver State  Receiver Postal Code Receiver Country  \
# 0        MCCLELLAN             CA               95652.0               US
# 1             RENO             NV           895111294.0               US
# 2       STILLWATER             OK           740743147.0               US
# 3           Muncie             IN               47306.0               US
# 4          ROSWELL             GA           300762167.0               US
# ...            ...            ...                   ...              ...
# 2750    WEST HILLS             CA           913071496.0               US
# 2751        RAMONA             CA           920658106.0               US
customer Packaging  re.compile('\\w+/\\w+/\\w+')
# 3     Customer Packaging  re.compile('\\w+/\\w+/\\w+')
# 4     Customer Packaging  re.compile('\\w+/\\w+/\\w+')
# ...                  ...                           ...
# 2750  Customer Packaging  re.compile('\\w+/\\w+/\\w+')
# 2751  Customer Packaging  re.compile('\\w+/\\w+/\\w+')
# 2752  Customer Packaging  re.compile('\\w+/\\w+/\\w+')
# 2753  Customer Packaging  re.compile('\\w+/\\w+/\\w+')
# 2754  Customer Packaging            re.compile('\\d+')
#
# [2755 rows x 61 columns]

# %%
def add_pattern_column(invoice_data: pd.DataFrame) -> pd.DataFrame:
    """
    Function: Adds a column to the FedEx Invoice DataFrame with the RegEx pattern symbolizing 'Customer PO #'
    Input: FedEx Invoice DataFrame
    Output: DataFrame with added 'Pattern' column
    """

    def reg_tokenizer(value):

        with_letters = re.sub(r"[a-zA-Z]+", r"\\w+", str(value))
        with_numbers = re.sub(r"\d+", r"\\d+", with_letters)
        with_spaces = re.sub(r"\s+", r"\\s+", with_numbers)

        final = re.compile(with_spaces)

        return final

    token_lst = []

    for i in invoice_data["Reference"]:
        token_lst.append(reg_tokenizer(i))

    invoice_data["Pattern"] = token_lst

    return invoice_data

# %% [markdown]
# ### - Compare `not found`[Pattern] to values in Extensiv Tables

# %%
# Compare Reference Patterns against every value in Extensiv Table

def find_col_match(ext_table, ref_pattern):

    col_lst = set()

    for col in ext_table.columns:

        for value in ext_table[col]:

            if re.fullmatch(ref_pattern,str(value)):

                col_lst.add(col)
                break
            
            else:
                break

    if len(col_lst) != 0:
        return col_lst
    else:
        return None

# %%
# Test \d+ to AMT table 

find_col_match(amt, not_found['Pattern'][1])
# Out:
# {'AsnCandidate',
#  'Column1',
#  'CreatedByIdentifier.Id',
#  'Custom.TotalResults',
#  'CustomerIdentifier.Id',
#  'Index',
#  'LastModifiedByIdentifier.Id',
#  'LoadedState',
#  'OrderId',
#  'ParcelLabelType',
#  'RouteCandidate',
#  'RoutingInfo.BillOfLading',
#  'ShipTo.Zip',
#  'Status',
#  'TransactionEntryType',
#  'WarehouseTransactionSourceType'}

# %%
# Check AMT table

amt[['AsnCandidate',
 'Column1',
 'CreatedByIdentifier.Id',
 'Custom.TotalResults',
 'CustomerIdentifier.Id',
 'Index',
 'LastModifiedByIdentifier.Id',
 'LoadedState',
 'OrderId',
 'ParcelLabelType',
 'RouteCandidate',
 'RoutingInfo.BillOfLading',
 'ShipTo.Zip',
 'Status',
 'TransactionEntryType',
 'WarehouseTransactionSourceType']].head()
# Out:
#    AsnCandidate  Column1  CreatedByIdentifier.Id  Custom.TotalResults  \
# 0             0        0                      10                 1044
# 1             0        0                      10                 1044
# 2             0        0                      10                 1044
# 3             0        0                      10                 1044
# 4             0        0                      10                 1044
#
#    CustomerIdentifier.Id  Index  LastModifiedByIdentifier.Id  LoadedState  \
# 0                     11      1                           10            0
# 1                     11      1                           10            0
# 2                     11      1                           10            0
# 3                     11      1                           10            0
# 4                     11      1                           10            0
#
#    OrderId  ParcelLabelType  RouteCandidate RoutingInfo.BillOfLading  \
# 0      363                0               0                       17
# 1      363                0               0                       17
# 2      363                0               0                       17
# 3      363                0               0                       17
# 4      363                0               0                       17
#
#   ShipTo.Zip  Status  TransactionEntryType  WarehouseTransactionSourceType
# 0      52404       1                     1                               1
# 1      52404       1                     1                               1
# 2      52404       1                     1                               1
# 3      52404       1                     1                               1
# 4      52404       1                     1                               1

# %% [markdown]
# ### - Compare all `not_found`[Reference], `not_found`[Pattern] values to Extensiv Table

# %%
def find_extensiv_reference_columns(extensiv_table: pd.DataFrame, invoice_data_w_patterns: pd.DataFrame) -> dict:  # fmt: skip
    """
    Function: Finds all of the columns in the Extensiv table that match each 'Reference' in FedEx Invoice not in QBO
    Input: Extensiv DataFrame, FedEx Invoice DataFrame w/ added 'Pattern' column
    Ouput: Dictionary {'match_lst': list of Extensiv columns that match 'Reference' pattern,
                       'Total Charges': Charges associated with that 'Reference' in FedEx Invoice,
                       'Tracking #': Tracking number associated with that 'Reference' in FedEx Invoice}
    Notes: May not need Total Charges and Tracking # in the end
    """

    def find_col_match(extensiv_table: pd.DataFrame, ref_pattern: pd.Series) -> list:
        """
        Function: Subfunction to iterate through each of the patterns in FedEx Invoice
        Input: Extensiv DataFrame, FedEx Reference patterns as a Series in a for loop
        Ouput: List of columns that match given Reference pattern
        """
        col_lst = set()

        for col in extensiv_table.columns:

            for value in extensiv_table[col]:

                if re.fullmatch(ref_pattern, str(value)):

                    col_lst.add(col)
                    break

                else:
                    break

        if len(col_lst) != 0:
            return col_lst
        else:
            return None

    match_dct = dict()
    suffix = 0

    for i, v in enumerate(invoice_data_w_patterns["Reference"]):

        if i != 0 and v == invoice_data_w_patterns["Reference"][i - 1]:

            suffix += 1
            v = f"{v}-s{suffix}"

        elif i != 0 and v != invoice_data_w_patterns["Reference"][i - 1]:
            suffix = 0
        else:
            continue

        match_lst = find_col_match(
            extensiv_table, invoice_data_w_patterns["Pattern"][i]
        )

        if match_lst is not None and not pd.isna(v):

            match_dct[v] = {
                "match_lst": match_lst,
                "Total Charges": invoice_data_w_patterns["Total Charges"][i],
                "Tracking #": invoice_data_w_patterns["Tracking #"][i],
            }

    return match_dct

# %%
# Test Find column matches

amt_match_dct = find_extensiv_reference_columns(amt, not_found)
gp_acoustics_dct = find_extensiv_reference_columns(gp_acoustics, not_found)

# %%
# Reference numbers in FedEx and matching columns in Extensiv 

gp_acoustics_dct
# Out:
# {10569: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(5.91),
#   'Tracking #': np.int64(280881789594)},
#  11653: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(30.42),
#   'Tracking #': np.int64(280887141570)},
#  '11653-s1': {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(15.9),
#   'Tracking #': np.int64(280887141179)},
#  '11653-s2': {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(20.17),
#   'Tracking #': np.int64(280887148015)},
#  '11653-s3': {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(22.14),
#   'Tracking #': np.int64(280887144903)},
#  '11653-s4': {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(21.44),
#   'Tracking #': np.int64(280887146766)},
#  10566: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(9.56),
#   'Tracking #': np.int64(280881955477)},
#  14371: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(9.62),
#   'Tracking #': np.int64(281397637770)},
#  11391: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(9.56),
#   'Tracking #': np.int64(280766989314)},
#  '11391-s1': {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(11.18),
#   'Tracking #': np.int64(280766986668)},
#  14273: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(103.43),
#   'Tracking #': np.int64(281378876230)},
#  11584: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(107.44),
#   'Tracking #': np.int64(280862770590)},
#  'Event Sample': {'match_lst': {'CreatedByIdentifier.Name',
#    'CustomerIdentifier.Name',
#    'LastModifiedByIdentifier.Name',
#    'ShipTo.City'},
#   'Total Charges': np.float64(19.79),
#   'Tracking #': np.int64(418132348817)},
#  11627: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(110.56),
#   'Tracking #': np.int64(280863094183)},
#  13730: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(22.44),
#   'Tracking #': np.int64(281241623171)},
#  '13730-s1': {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(12.15),
#   'Tracking #': np.int64(281241622510)},
#  '13730-s2': {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(22.44),
#   'Tracking #': np.int64(281241625601)},
#  '13730-s3': {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(22.44),
#   'Tracking #': np.int64(281241624237)},
#  14901: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(106.85),
#   'Tracking #': np.int64(281636958213)},
#  11397: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(9.56),
#   'Tracking #': np.int64(280768308100)},
#  10567: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(9.56),
#   'Tracking #': np.int64(280882052528)},
#  198460: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(11.43),
#   'Tracking #': np.int64(418132350302)},
#  11514: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(106.73),
#   'Tracking #': np.int64(280791284071)},
#  10548: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(4.85),
#   'Tracking #': np.int64(280881319542)},
#  10557: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(5.55),
#   'Tracking #': np.int64(280881846057)},
#  14324: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(106.98),
#   'Tracking #': np.int64(281378830569)},
#  13700: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(15.81),
#   'Tracking #': np.int64(281249653359)},
#  13282: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(106.98),
#   'Tracking #': np.int64(281075499427)},
#  13903: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(4.85),
#   'Tracking #': np.int64(281242712302)},
#  10565: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(14.17),
#   'Tracking #': np.int64(280882160702)},
#  11905: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(106.73),
#   'Tracking #': np.int64(280981724902)},
#  13765: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(17.18),
#   'Tracking #': np.int64(281248581945)},
#  '13765-s1': {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(18.25),
#   'Tracking #': np.int64(281248585790)},
#  '13765-s2': {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(17.18),
#   'Tracking #': np.int64(281248582091)},
#  '13765-s3': {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(18.25),
#   'Tracking #': np.int64(281248583672)},
#  11844: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(7.7),
#   'Tracking #': np.int64(280986894281)},
#  11396: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(9.56),
#   'Tracking #': np.int64(280807219242)},
#  13390: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(23.69),
#   'Tracking #': np.int64(281142406523)},
#  '13390-s1': {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(23.31),
#   'Tracking #': np.int64(281142405045)},
#  14552: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(106.98),
#   'Tracking #': np.int64(281435191263)},
#  15000: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(98.93),
#   'Tracking #': np.int64(281720177427)},
#  14678: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(21.44),
#   'Tracking #': np.int64(418132350313)},
#  '14678-s1': {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(19.96),
#   'Tracking #': np.int64(418132350335)},
#  '14678-s2': {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(25.12),
#   'Tracking #': np.int64(418132350324)},
#  'Customer Box': {'match_lst': {'CreatedByIdentifier.Name',
#    'CustomerIdentifier.Name',
#    'LastModifiedByIdentifier.Name',
#    'ShipTo.City'},
#   'Total Charges': np.float64(11.65),
#   'Tracking #': np.int64(418132350265)},
#  10561: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(7.47),
#   'Tracking #': np.int64(280881613185)},
#  10563: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(5.56),
#   'Tracking #': np.int64(280881729544)},
#  11503: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(106.73),
#   'Tracking #': np.int64(280791342402)},
#  14743: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(7.29),
#   'Tracking #': np.int64(281567086557)},
#  10556: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(4.92),
#   'Tracking #': np.int64(280881537650)},
#  10554: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(6.54),
#   'Tracking #': np.int64(280881245477)},
#  11348: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(106.73),
#   'Tracking #': np.int64(280754149646)},
#  11912: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(8.54),
#   'Tracking #': np.int64(280986780422)},
#  11523: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(19.93),
#   'Tracking #': np.int64(280791161446)},
#  14902: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(110.68),
#   'Tracking #': np.int64(281637062560)},
#  10564: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(5.18),
#   'Tracking #': np.int64(280882000233)},
#  13157: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(9.39),
#   'Tracking #': np.int64(281058904347)},
#  13158: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(24.42),
#   'Tracking #': np.int64(281058966643)},
#  '13158-s1': {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(24.42),
#   'Tracking #': np.int64(281058965268)},
#  15116: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(5.17),
#   'Tracking #': np.int64(281752495934)},
#  14821: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(103.43),
#   'Tracking #': np.int64(281566654210)},
#  10555: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(5.85),
#   'Tracking #': np.int64(280881370665)},
#  10562: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(10.63),
#   'Tracking #': np.int64(280881473027)},
#  '10562-s1': {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(9.39),
#   'Tracking #': np.int64(280881474940)},
#  13405: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(103.43),
#   'Tracking #': np.int64(281138823384)},
#  'GP Acoustics': {'match_lst': {'CreatedByIdentifier.Name',
#    'CustomerIdentifier.Name',
#    'LastModifiedByIdentifier.Name',
#    'ShipTo.City'},
#   'Total Charges': np.float64(11.9),
#   'Tracking #': np.int64(418132348770)},
#  'GP Acoustics-s1': {'match_lst': {'CreatedByIdentifier.Name',
#    'CustomerIdentifier.Name',
#    'LastModifiedByIdentifier.Name',
#    'ShipTo.City'},
#   'Total Charges': np.float64(11.9),
#   'Tracking #': np.int64(418132348758)},
#  'GP Acoustics-s2': {'match_lst': {'CreatedByIdentifier.Name',
#    'CustomerIdentifier.Name',
#    'LastModifiedByIdentifier.Name',
#    'ShipTo.City'},
#   'Total Charges': np.float64(11.9),
#   'Tracking #': np.int64(418132348769)},
#  'GP Acoustics-s3': {'match_lst': {'CreatedByIdentifier.Name',
#    'CustomerIdentifier.Name',
#    'LastModifiedByIdentifier.Name',
#    'ShipTo.City'},
#   'Total Charges': np.float64(11.9),
#   'Tracking #': np.int64(418132348747)},
#  198370: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(23.35),
#   'Tracking #': np.int64(418132350368)},
#  'Whill Inc': {'match_lst': {'CreatedByIdentifier.Name',
#    'CustomerIdentifier.Name',
#    'LastModifiedByIdentifier.Name',
#    'ShipTo.City'},
#   'Total Charges': np.float64(39.0),
#   'Tracking #': np.int64(418132350379)},
#  10474: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(6.51),
#   'Tracking #': np.int64(281571300596)},
#  14704: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(20.66),
#   'Tracking #': np.int64(281669144489)},
#  '14704-s1': {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(4.85),
#   'Tracking #': np.int64(281669148820)},
#  14794: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(106.98),
#   'Tracking #': np.int64(281546944248)},
#  14797: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(11.14),
#   'Tracking #': np.int64(281570010710)},
#  14800: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(11.14),
#   'Tracking #': np.int64(281570078533)},
#  14801: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(11.14),
#   'Tracking #': np.int64(281570127730)},
#  14802: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(35.46),
#   'Tracking #': np.int64(281570230637)},
#  14811: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(19.46),
#   'Tracking #': np.int64(281570277690)},
#  14814: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(11.14),
#   'Tracking #': np.int64(281570465854)},
#  14836: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(11.14),
#   'Tracking #': np.int64(281570352428)},
#  14869: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(11.14),
#   'Tracking #': np.int64(281591257642)},
#  14877: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(11.14),
#   'Tracking #': np.int64(281591313370)},
#  14880: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(11.14),
#   'Tracking #': np.int64(281591361199)},
#  14881: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(11.12),
#   'Tracking #': np.int64(281648839995)},
#  14979: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(11.12),
#   'Tracking #': np.int64(281670208579)},
#  15021: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(11.88),
#   'Tracking #': np.int64(281706929401)},
#  355344: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(6.94),
#   'Tracking #': np.int64(281756336950)},
#  '355344-s1': {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(6.8),
#   'Tracking #': np.int64(281756340286)},
#  '355344-s2': {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(6.8),
#   'Tracking #': np.int64(281756336938)},
#  '355344-s3': {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(6.53),
#   'Tracking #': np.int64(281756339363)},
#  10559: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(12.1),
#   'Tracking #': np.int64(280882098840)},
#  14866: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(103.43),
#   'Tracking #': np.int64(281581789890)},
#  11614: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(101.28),
#   'Tracking #': np.int64(280862887420)},
#  11934: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(10.85),
#   'Tracking #': np.int64(280986974282)},
#  10560: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(8.21),
#   'Tracking #': np.int64(280881903399)},
#  15151: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(11.96),
#   'Tracking #': np.int64(281708821710)},
#  10558: {'match_lst': {'AsnCandidate',
#    'Column1',
#    'CreatedByIdentifier.Id',
#    'Custom.TotalResults',
#    'CustomerIdentifier.Id',
#    'Index',
#    'LoadedState',
#    'OrderId',
#    'ParcelLabelType',
#    'ReferenceNum',
#    'RouteCandidate',
#    'RoutingInfo.BillOfLading',
#    'RoutingInfo.Mode',
#    'RoutingInfo.TrackingNumber',
#    'ShipTo.AddressStatus',
#    'ShipTo.ContactId',
#    'ShipTo.Zip',
#    'Status',
#    'TransactionEntryType',
#    'WarehouseTransactionSourceType'},
#   'Total Charges': np.float64(4.92),
#   'Tracking #': np.int64(280881667358)}}

# %% [markdown]
# ### - Compare each `not_found`[Reference] to each value in matched Extensiv columns

# %%
def find_value_match(extensiv_table: pd.DataFrame, reference_matches: dict) -> list:

    match_lst = list()

    for reference in reference_matches:

        matches = reference_matches[reference]["match_lst"]
        total_charges = reference_matches[reference]["Total Charges"]
        tracking_number = reference_matches[reference]["Tracking #"]

        for col in extensiv_table[list(matches)]:

            for i, val in enumerate(extensiv_table[col]):

                base_reference = re.sub(r"-s\d+$", "", str(reference))

                if val == reference or val == base_reference:

                    match_entry = {
                        "Reference": base_reference,
                        "Name": extensiv_table["CustomerIdentifier.Name"][i],
                        "Column": col,
                        "Total Charges": total_charges,
                        "Tracking #": tracking_number,
                    }

                    if match_entry not in match_lst:
                        match_lst.append(match_entry)
                else:
                    continue

    if not match_lst:
        print(f"No Matches")

    else:
        return match_lst

# %%
# amt_reference_matches = find_value_match(gp_acoustics, gp_acoustics_dct)
gp_reference_matches = find_value_match(gp_acoustics, gp_acoustics_dct)

# %%
gp_reference_matches
# Out:
# [{'Reference': '10569',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(5.91),
#   'Tracking #': np.int64(280881789594)},
#  {'Reference': '11653',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(30.42),
#   'Tracking #': np.int64(280887141570)},
#  {'Reference': '10566',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(9.56),
#   'Tracking #': np.int64(280881955477)},
#  {'Reference': '14371',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(9.62),
#   'Tracking #': np.int64(281397637770)},
#  {'Reference': '11391',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(9.56),
#   'Tracking #': np.int64(280766989314)},
#  {'Reference': '13730',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(22.44),
#   'Tracking #': np.int64(281241623171)},
#  {'Reference': '11397',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(9.56),
#   'Tracking #': np.int64(280768308100)},
#  {'Reference': '10567',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(9.56),
#   'Tracking #': np.int64(280882052528)},
#  {'Reference': '10548',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(4.85),
#   'Tracking #': np.int64(280881319542)},
#  {'Reference': '10557',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(5.55),
#   'Tracking #': np.int64(280881846057)},
#  {'Reference': '13700',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(15.81),
#   'Tracking #': np.int64(281249653359)},
#  {'Reference': '13903',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(4.85),
#   'Tracking #': np.int64(281242712302)},
#  {'Reference': '10565',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(14.17),
#   'Tracking #': np.int64(280882160702)},
#  {'Reference': '13765',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(17.18),
#   'Tracking #': np.int64(281248581945)},
#  {'Reference': '11844',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(7.7),
#   'Tracking #': np.int64(280986894281)},
#  {'Reference': '11396',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(9.56),
#   'Tracking #': np.int64(280807219242)},
#  {'Reference': '13390',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(23.69),
#   'Tracking #': np.int64(281142406523)},
#  {'Reference': '10561',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(7.47),
#   'Tracking #': np.int64(280881613185)},
#  {'Reference': '10563',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(5.56),
#   'Tracking #': np.int64(280881729544)},
#  {'Reference': '14743',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(7.29),
#   'Tracking #': np.int64(281567086557)},
#  {'Reference': '10556',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(4.92),
#   'Tracking #': np.int64(280881537650)},
#  {'Reference': '10554',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(6.54),
#   'Tracking #': np.int64(280881245477)},
#  {'Reference': '11912',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(8.54),
#   'Tracking #': np.int64(280986780422)},
#  {'Reference': '11523',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(19.93),
#   'Tracking #': np.int64(280791161446)},
#  {'Reference': '10564',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(5.18),
#   'Tracking #': np.int64(280882000233)},
#  {'Reference': '13157',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(9.39),
#   'Tracking #': np.int64(281058904347)},
#  {'Reference': '13158',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(24.42),
#   'Tracking #': np.int64(281058966643)},
#  {'Reference': '15116',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(5.17),
#   'Tracking #': np.int64(281752495934)},
#  {'Reference': '10555',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(5.85),
#   'Tracking #': np.int64(280881370665)},
#  {'Reference': '10562',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(10.63),
#   'Tracking #': np.int64(280881473027)},
#  {'Reference': 'GP Acoustics',
#   'Name': 'GP Acoustics',
#   'Column': 'CustomerIdentifier.Name',
#   'Total Charges': np.float64(11.9),
#   'Tracking #': np.int64(418132348770)},
#  {'Reference': 'GP Acoustics',
#   'Name': 'GP Acoustics',
#   'Column': 'CustomerIdentifier.Name',
#   'Total Charges': np.float64(11.9),
#   'Tracking #': np.int64(418132348758)},
#  {'Reference': 'GP Acoustics',
#   'Name': 'GP Acoustics',
#   'Column': 'CustomerIdentifier.Name',
#   'Total Charges': np.float64(11.9),
#   'Tracking #': np.int64(418132348769)},
#  {'Reference': 'GP Acoustics',
#   'Name': 'GP Acoustics',
#   'Column': 'CustomerIdentifier.Name',
#   'Total Charges': np.float64(11.9),
#   'Tracking #': np.int64(418132348747)},
#  {'Reference': '10559',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(12.1),
#   'Tracking #': np.int64(280882098840)},
#  {'Reference': '11934',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(10.85),
#   'Tracking #': np.int64(280986974282)},
#  {'Reference': '10560',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(8.21),
#   'Tracking #': np.int64(280881903399)},
#  {'Reference': '10558',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(4.92),
#   'Tracking #': np.int64(280881667358)}]

# %%
# for i, row in not_found.iterrows():
#     # print(row['Reference'])
#     for dct in gp_found_values:
        
#         try:
#             dct['Reference'] = int(dct['Reference'])  # Convert to integer
#         except ValueError:
#             pass
#         # print(dct['Reference'])
#         if dct['Reference'] == row['Reference']:
#             not_found.loc[i,'Customer PO #'] = dct['Name']
# not_found

# %%
not_found[(not_found['Customer PO #'] == 'GP Acoustics')]
# Out:
# Empty DataFrame
# Columns: [Customer PO #, Shipper #, Invoice #, Invoice Date, Invoice Amount, Tracking #, Ship Date, Delivery Date, Delivery Time, Service Level, Zone, Reference, Department, Bill Option, Piece Count, Actual Weight, Bill Weight, Cwt Weight, Ship Device, Shipper Name, Shipper Company, Shipper Address, Shipper City, Shipper State, Shipper Postal Code, Shipper Country, Receiver Account, Receiver Name, Receiver Company, Receiver Address, Receiver City, Receiver State, Receiver Postal Code, Receiver Country, Customer Dept. #, Customer Invoice #, Declared Value, Customs Value, GL Code, Shipper Account, Reference 2, Length, Width, Height, Control #, Credit Reason, Published Amount, Discounted Amount, Residential, DAS, Fuel, Saturday Delivery, Add'd Handling, Misc. Charges, Client , Coding, Total Charges, Adjusted Amount, Audited Amount, Service Packaging, Pattern]
# Index: []

# %% [markdown]
# # **Invoice Data** [`Receiver Info`] <-> **Extensiv** [`Receiver Info`]

# %%
def create_extensiv_receiver_info(extensiv_table: pd.DataFrame) -> dict:

    extensiv_receiver_info = extensiv_table[
        [
            "ShipTo.CompanyName",
            "ShipTo.Name",
            "ShipTo.Address1",
            "CustomerIdentifier.Name",
        ]
    ]

    extensiv_receiver_info_nd = extensiv_receiver_info.drop_duplicates(
        [
            "ShipTo.CompanyName",
            "ShipTo.Name",
            "ShipTo.Address1",
            "CustomerIdentifier.Name",
        ]
    )

    extensiv_receiver_dct = dict()

    for i, row in extensiv_receiver_info_nd.iterrows():

        extensiv_receiver_dct[i] = {
            "Receiver Address": row["ShipTo.Address1"],
            "Receiver Company": row["ShipTo.CompanyName"],
            "Receiver Name": row["ShipTo.Name"],
            "Customer Identifier": row["CustomerIdentifier.Name"],
        }

    return extensiv_receiver_dct

# %%
def create_invoice_data_receiver_info(invoice_data: pd.DataFrame, reference_matches: list) -> dict:  # fmt: skip

    found_reference_lst = list()

    for i in reference_matches:
        found_reference_lst.append(i["Reference"])

    #! Taking out this conditional to test
    invoice_data_null = invoice_data[
        (invoice_data["Customer PO #"].isna())
        & ~(invoice_data["Reference"].isin(found_reference_lst))
    ]

    invoice_data_dct = {}

    for i, row in invoice_data.iterrows():

        invoice_data_dct[i] = {
            "Receiver Address": row["Receiver Address"],
            "Receiver Company": row["Receiver Company"],
            "Receiver Name": row["Receiver Name"],
            "Tracking #": row["Tracking #"],
        }

    return invoice_data_dct

# %%
gp_receiver_info = create_extensiv_receiver_info(gp_acoustics)
invoice_data_receiver_info = create_invoice_data_receiver_info(invoice_data, gp_reference_matches)

# %%
def compare_receiver_info(invoice_data_receiver_info: dict, extensiv_receiver_info: dict) -> list:  # fmt: skip

    match_entry = dict()
    match_lst = list()

    for i in invoice_data_receiver_info:

        for e in extensiv_receiver_info:

            if (
                invoice_data_receiver_info[i]["Receiver Address"]
                == extensiv_receiver_info[e]["Receiver Address"]
                or invoice_data_receiver_info[i]["Receiver Name"]
                == extensiv_receiver_info[e]["Receiver Name"]
                or invoice_data_receiver_info[i]["Receiver Company"]
                == extensiv_receiver_info[e]["Receiver Company"]
            ):

                match_entry = {
                    "Address": invoice_data_receiver_info[i]["Receiver Address"],
                    "Name": invoice_data_receiver_info[i]["Receiver Name"],
                    "Company": invoice_data_receiver_info[i]["Receiver Company"],
                    "Customer": extensiv_receiver_info[e]["Customer Identifier"],
                }

                if match_entry not in match_lst:
                    match_lst.append(match_entry)

    if match_lst:
        return pd.DataFrame(match_lst)
    else:
        print("No Match")

# %%
gp_receiver_matches = compare_receiver_info(invoice_data_receiver_info, gp_receiver_info)

# %%
len(gp_receiver_matches)
# Out:
# 11

# %%
final_matches_lst = []
final_matches_lst.extend(gp_reference_matches)
final_matches_lst.extend(gp_receiver_matches)

# %%
final_matches_lst
# Out:
# [{'Reference': '10569',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(5.91),
#   'Tracking #': np.int64(280881789594)},
#  {'Reference': '11653',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(30.42),
#   'Tracking #': np.int64(280887141570)},
#  {'Reference': '10566',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(9.56),
#   'Tracking #': np.int64(280881955477)},
#  {'Reference': '14371',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(9.62),
#   'Tracking #': np.int64(281397637770)},
#  {'Reference': '11391',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(9.56),
#   'Tracking #': np.int64(280766989314)},
#  {'Reference': '13730',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(22.44),
#   'Tracking #': np.int64(281241623171)},
#  {'Reference': '11397',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(9.56),
#   'Tracking #': np.int64(280768308100)},
#  {'Reference': '10567',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(9.56),
#   'Tracking #': np.int64(280882052528)},
#  {'Reference': '10548',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(4.85),
#   'Tracking #': np.int64(280881319542)},
#  {'Reference': '10557',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(5.55),
#   'Tracking #': np.int64(280881846057)},
#  {'Reference': '13700',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(15.81),
#   'Tracking #': np.int64(281249653359)},
#  {'Reference': '13903',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(4.85),
#   'Tracking #': np.int64(281242712302)},
#  {'Reference': '10565',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(14.17),
#   'Tracking #': np.int64(280882160702)},
#  {'Reference': '13765',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(17.18),
#   'Tracking #': np.int64(281248581945)},
#  {'Reference': '11844',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(7.7),
#   'Tracking #': np.int64(280986894281)},
#  {'Reference': '11396',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(9.56),
#   'Tracking #': np.int64(280807219242)},
#  {'Reference': '13390',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(23.69),
#   'Tracking #': np.int64(281142406523)},
#  {'Reference': '10561',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(7.47),
#   'Tracking #': np.int64(280881613185)},
#  {'Reference': '10563',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(5.56),
#   'Tracking #': np.int64(280881729544)},
#  {'Reference': '14743',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(7.29),
#   'Tracking #': np.int64(281567086557)},
#  {'Reference': '10556',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(4.92),
#   'Tracking #': np.int64(280881537650)},
#  {'Reference': '10554',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(6.54),
#   'Tracking #': np.int64(280881245477)},
#  {'Reference': '11912',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(8.54),
#   'Tracking #': np.int64(280986780422)},
#  {'Reference': '11523',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(19.93),
#   'Tracking #': np.int64(280791161446)},
#  {'Reference': '10564',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(5.18),
#   'Tracking #': np.int64(280882000233)},
#  {'Reference': '13157',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(9.39),
#   'Tracking #': np.int64(281058904347)},
#  {'Reference': '13158',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(24.42),
#   'Tracking #': np.int64(281058966643)},
#  {'Reference': '15116',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(5.17),
#   'Tracking #': np.int64(281752495934)},
#  {'Reference': '10555',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(5.85),
#   'Tracking #': np.int64(280881370665)},
#  {'Reference': '10562',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(10.63),
#   'Tracking #': np.int64(280881473027)},
#  {'Reference': 'GP Acoustics',
#   'Name': 'GP Acoustics',
#   'Column': 'CustomerIdentifier.Name',
#   'Total Charges': np.float64(11.9),
#   'Tracking #': np.int64(418132348770)},
#  {'Reference': 'GP Acoustics',
#   'Name': 'GP Acoustics',
#   'Column': 'CustomerIdentifier.Name',
#   'Total Charges': np.float64(11.9),
#   'Tracking #': np.int64(418132348758)},
#  {'Reference': 'GP Acoustics',
#   'Name': 'GP Acoustics',
#   'Column': 'CustomerIdentifier.Name',
#   'Total Charges': np.float64(11.9),
#   'Tracking #': np.int64(418132348769)},
#  {'Reference': 'GP Acoustics',
#   'Name': 'GP Acoustics',
#   'Column': 'CustomerIdentifier.Name',
#   'Total Charges': np.float64(11.9),
#   'Tracking #': np.int64(418132348747)},
#  {'Reference': '10559',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(12.1),
#   'Tracking #': np.int64(280882098840)},
#  {'Reference': '11934',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(10.85),
#   'Tracking #': np.int64(280986974282)},
#  {'Reference': '10560',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(8.21),
#   'Tracking #': np.int64(280881903399)},
#  {'Reference': '10558',
#   'Name': 'GP Acoustics',
#   'Column': 'OrderId',
#   'Total Charges': np.float64(4.92),
#   'Tracking #': np.int64(280881667358)},
#  'Address',
#  'Name',
#  'Company',
#  'Customer']

# %%
for i, row in not_found.iterrows():
    for dct in final_matches_lst:
        
        if 'Reference' in dct and dct['Reference'] == row['Reference']:
            not_found.loc[i, 'Customer PO #'] = dct['Name']
        elif 'Address' in dct and dct['Address'] == row['Receiver Address']:
            not_found.loc[i, 'Customer PO #'] = dct['Customer']
        elif 'Name' in dct and dct['Name'] == row['Receiver Name']:
            not_found.loc[i, 'Customer PO #'] = dct['Customer']
        elif 'Company' in dct and dct['Company'] == row['Receiver Company']:
            not_found.loc[i, 'Customer PO #'] = dct['Customer']
        elif 'Reference' in dct:
            try:
                dct['Reference'] = int(dct['Reference'])
            except ValueError:
                pass

# %%
not_found[not_found['Customer PO #'] == 'GP Acoustics']
# Out:
#      Customer PO #  Shipper #  Invoice # Invoice Date  Invoice Amount  \
# 0     GP Acoustics  693070511  867618863   2024-11-08        29866.52
# 1     GP Acoustics  693070511  867618863   2024-11-08        29866.52
# 2     GP Acoustics  693070511  867618863   2024-11-08        29866.52
# 3     GP Acoustics  693070511  867618863   2024-11-08        29866.52
# 443   GP Acoustics  693070511  868389946   2024-11-15        27353.46
# 444   GP Acoustics  693070511  866891361   2024-11-01        21136.17
# 1072  GP Acoustics  693070511  866891361   2024-11-01        21136.17
# 1140  GP Acoustics  693070511  867618863   2024-11-08        29866.52
# 1141  GP Acoustics  693070511  867618864   2024-11-08        25739.62
# 1142  GP Acoustics  693070511  867618864   2024-11-08        25739.62
# 1143  GP Acoustics  693070511  867618865   2024-11-08        18523.17
# 1144  GP Acoustics  693070511  867618865   2024-11-08        18523.17
# 1145  GP Acoustics  693070511  867618865   2024-11-08        18523.17
# 1146  GP Acoustics  693070511  867618865   2024-11-08        18523.17
# 1147  GP Acoustics  693070511  866891361   2024-11-01        21136.17
# 1148  GP Acoustics  693070511  867618865   2024-11-08        18523.17
# 1149  GP Acoustics  693070511  866891360   2024-11-01        24182.11
# 1152  GP Acoustics  693070511  867618863   2024-11-08        29866.52
# 1153  GP Acoustics  693070511  866891360   2024-11-01        24182.11
# 1154  GP Acoustics  693070511  866891361   2024-11-01        21136.17
# 1174  GP Acoustics  693070511  867618865   2024-11-08        18523.17
# 1175  GP Acoustics  693070511  867618865   2024-11-08        18523.17
# 1176  GP Acoustics  693070511  867618865   2024-11-08        18523.17
# 1177  GP Acoustics  693070511  867618865   2024-11-08        18523.17
# 1178  GP Acoustics  693070511  866891361   2024-11-01        21136.17
# 1186  GP Acoustics  693070511  866891361   2024-11-01        21136.17
# 1187  GP Acoustics  693070511  866891360   2024-11-01        24182.11
# 1803  GP Acoustics  693070511  866891361   2024-11-01        21136.17
# 1804  GP Acoustics  693070511  866891362   2024-11-01        37778.60
# 1808  GP Acoustics  693070511  869086369   2024-11-22        25820.77
# 1809  GP Acoustics  693070511  866891360   2024-11-01        24182.11
# 1810  GP Acoustics  693070511  866891360   2024-11-01        24182.11
# 1811  GP Acoustics  693070511  866891361   2024-11-01        21136.17
# 1812  GP Acoustics  693070511  866891361   2024-11-01        21136.17
# 1813  GP Acoustics  693070511  866891361   2024-11-01        21136.17
# 1814  GP Acoustics  693070511  866891361   2024-11-01        21136.17
# 2150  GP Acoustics  693070511  866891360   2024-11-01        24182.11
# 2152  GP Acoustics  693070511  866891360   2024-11-01        24182.11
# 2154  GP Acoustics  693070511  867618864   2024-11-08        25739.62
# 2155  GP Acoustics  693070511  866891360   2024-11-01        24182.11
# 2156  GP Acoustics  693070511  866891361   2024-11-01        21136.17
# 2157  GP Acoustics  693070511  867618865   2024-11-08        18523.17
# 2158  GP Acoustics  693070511  866891360   2024-11-01        24182.11
# 2159  GP Acoustics  693070511  866891360   2024-11-01        24182.11
# 
# 2162           916056219.0               US               NaN
# 2163           386544017.0               US               NaN
# 2700           436161430.0               US               NaN
# 2703           393058733.0               US               NaN
# 2719           109402120.0               US               NaN
# 2720           109402120.0               US               NaN
#
#       Customer Invoice #  Declared Value  Customs Value  GL Code  \
# 0                    NaN               0              0      NaN
# 1                    NaN               0              0      NaN
# 2                    NaN               0              0      NaN
# 3                    NaN               0              0      NaN
# 443                  NaN               0              0      NaN
# 444                  NaN               0              0      NaN
# 1072                 NaN               0              0      NaN
# 1140                 NaN               0              0      NaN
# 1141                 NaN               0              0      NaN
# 1142                 NaN               0              0      NaN
# 1143                 NaN               0              0      NaN
# 1144                 NaN               0              0      NaN
# 1145                 NaN               0              0      NaN
# 1146                 NaN               0              0      NaN
# 1147                 NaN               0              0      NaN
# 1148                 NaN               0              0      NaN
# 1149                 NaN               0              0      NaN
# 1152                 NaN               0              0      NaN
# 1153                 NaN               0              0      NaN
# 1154                 NaN               0              0      NaN
# 1174                 NaN               0              0      NaN
# 1175                 NaN               0              0      NaN
# 1176                 NaN               0              0      NaN
# 1177                 NaN               0              0      NaN
# 1178                 NaN               0              0      NaN
# 1186                 NaN               0              0      NaN
# 1187                 NaN               0              0      NaN
# 1803                 NaN               0              0      NaN
# 1804                 NaN               0              0      NaN
# 1808                 NaN               0              0      NaN
# 1809                 NaN               0              0      NaN
# 1810                 NaN               0              0      NaN
# 1811                 NaN               0              0      NaN
# 1812                 NaN               0              0      NaN
# 1813                 NaN               0              0      NaN
# 1814                 NaN               0              0      NaN
# 2150                 NaN               0              0      NaN
# 2152                 NaN               0              0      NaN
# 2154                 NaN               0              0      NaN
# 2155                 NaN               0              0      NaN
# 2156                 NaN               0              0      NaN
# 2157                 NaN               0              0      NaN
# 2158                 NaN               0              0      NaN
# 2159                 NaN               0              0      NaN
# 2160                 NaN               0              0      NaN
# 2161                 NaN               0              0      NaN
# 2162                 NaN               0              0      NaN
# 2163                 NaN               0              0      NaN
# 2700                 NaN               0              0      NaN
# 2703                 NaN               0              0      NaN
# 2719                 NaN               0              0      NaN
# 2720                 NaN               0              0      NaN
#
#       Shipper Account Reference 2  Length  Width  Height Control #  \
# 0           693070511         NaN      14     13      10  ADVA4456
# 1           693070511         NaN      14     13      10  ADVA4456
# 2           693070511         NaN      14     13      10  ADVA4456
# 3           693070511         NaN      14     13      10  ADVA4456
# 443         693070511         NaN      20     14      14  ADVA4465
# 444         693070511         NaN      14     14      14  ADVA4452
# 1072        693070511         NaN      14     14      14  ADVA4452
# 1140        693070511         NaN      20     14      14  ADVA4456
# 1141        693070511         NaN      24     14      14  ADVA4456
# 1142        693070511         NaN      24     14      14  ADVA4456
# 1143        693070511         NaN      26     14      14  ADVA4456
# 1144        693070511         NaN      24     14      14  ADVA4456
# 1145        693070511         NaN      26     14      14  ADVA4456
# 1146        693070511         NaN      26     14      14  ADVA4456
# 1147        693070511         NaN      20     14      14  ADVA4452
# 1148        693070511         NaN       9      7       5  ADVA4456
# 2158  59062/587120           8.21                0            8.21
# 2159  59062/587120           4.92                0            4.92
# 2160  59062/587120           9.56                0            9.56
# 2161  59062/587120          24.42                0           24.42
# 2162  59062/587120          24.42                0           24.42
# 2163  59062/587120           4.85                0            4.85
# 2700  59062/587120           5.56                0            5.56
# 2703  59062/587120           7.29                0            7.29
# 2719  59062/587120           9.56                0            9.56
# 2720  59062/587120          11.18                0           11.18
#
#        Service Packaging                     Pattern
# 0     Customer Packaging  re.compile('\\w+\\s+\\w+')
# 1     Customer Packaging  re.compile('\\w+\\s+\\w+')
# 2     Customer Packaging  re.compile('\\w+\\s+\\w+')
# 3     Customer Packaging  re.compile('\\w+\\s+\\w+')
# 443   Customer Packaging          re.compile('\\d+')
# 444   Customer Packaging          re.compile('\\d+')
# 1072  Customer Packaging          re.compile('\\d+')
# 1140  Customer Packaging          re.compile('\\d+')
# 1141  Customer Packaging          re.compile('\\d+')
# 1142  Customer Packaging          re.compile('\\d+')
# 1143  Customer Packaging          re.compile('\\d+')
# 1144  Customer Packaging          re.compile('\\d+')
# 1145  Customer Packaging          re.compile('\\d+')
# 1146  Customer Packaging          re.compile('\\d+')
# 1147  Customer Packaging          re.compile('\\d+')
# 1148  Customer Packaging          re.compile('\\d+')
# 1149  Customer Packaging          re.compile('\\d+')
# 1152  Customer Packaging          re.compile('\\d+')
# 1153  Customer Packaging          re.compile('\\d+')
# 1154  Customer Packaging          re.compile('\\d+')
# 1174  Customer Packaging          re.compile('\\d+')
# 1175  Customer Packaging          re.compile('\\d+')
# 1176  Customer Packaging          re.compile('\\d+')
# 1177  Customer Packaging          re.compile('\\d+')
# 1178  Customer Packaging          re.compile('\\d+')
# 1186  Customer Packaging          re.compile('\\d+')
# 1187  Customer Packaging          re.compile('\\d+')
# 1803  Customer Packaging          re.compile('\\d+')
# 1804  Customer Packaging          re.compile('\\d+')
# 1808  Customer Packaging          re.compile('\\d+')
# 1809  Customer Packaging          re.compile('\\d+')
# 1810  Customer Packaging          re.compile('\\d+')
# 1811  Customer Packaging          re.compile('\\d+')
# 1812  Customer Packaging          re.compile('\\d+')
# 1813  Customer Packaging          re.compile('\\d+')
# 1814  Customer Packaging          re.compile('\\d+')
# 2150  Customer Packaging          re.compile('\\d+')
# 2152  Customer Packaging          re.compile('\\d+')
# 2154  Customer Packaging          re.compile('\\d+')
# 2155  Customer Packaging          re.compile('\\d+')
# 2156  Customer Packaging          re.compile('\\d+')
# 2157  Customer Packaging          re.compile('\\d+')
# 2158  Customer Packaging          re.compile('\\d+')
# 2159  Customer Packaging          re.compile('\\d+')
# 2160  Customer Packaging          re.compile('\\d+')
# 2161  Customer Packaging          re.compile('\\d+')
# 2162  Customer Packaging          re.compile('\\d+')
# 2163  Customer Packaging          re.compile('\\d+')
# 2700  Customer Packaging          re.compile('\\d+')
# 2703  Customer Packaging          re.compile('\\d+')
# 2719  Customer Packaging          re.compile('\\d+')
# 2720  Customer Packaging          re.compile('\\d+')

# %% [markdown]
# # MISC
